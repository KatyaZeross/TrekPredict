# %% [markdown]
# # Capstone Project: Star Trek IMDB Ratings Predictor
# ---
# ## INTRODUCTION
#
# - Goal: Predict the IMDB ratings from the scripts of Star Trek: The Next Generation.
#     - This can have very useful real world applications in the film industry. With a model like this, scriptwriters can refer to it and determine if the episode(s) may be a hit or miss based on the text data.
# - Data Acquistition (link to GitHub)
# - Goal in this notebook is to clean the dataset, and preprocess it for modeling, along with some handy visualizations.
#
# Let's begin by some EDA (Exploratory Data Analysis), as well as cleaning and modifying the data accordingly for our models.

# %%
# import all the relevant libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import regex as re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from collections import Counter
import string
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# ensure plots load inline
# %matplotlib inline
#give better plot style
plt.style.use('ggplot')

# %%
# read in the dataset
startrek_data = pd.read_csv(r'C:\Users\Katya\Documents\data\TNG.csv.gz', encoding= 'latin-1')

# %%
# take a look at the size
startrek_data.shape
# Out:
# (110176, 18)

# %% [markdown]
# There are 110,176 rows and 18 columns in this dataset. Let's take a look at it.

# %%
startrek_data.head()
# Out:
#    Unnamed: 0                episode productionnumber setnames characters  \
# 0           1  encounter at farpoint              NaN      NaN        NaN
# 1           2  encounter at farpoint              NaN      NaN        NaN
# 2           3  encounter at farpoint              NaN      NaN        NaN
# 3           4  encounter at farpoint              NaN      NaN        NaN
# 4           5  encounter at farpoint              NaN      NaN        NaN
#
#       act scenenumber  scenedetails  partnumber         type           who  \
# 0  TEASER         1             NaN           1  description           NaN
# 1  TEASER         1             NaN           2       speech   PICARD V.O.
# 2  TEASER         2             NaN           3  description           NaN
# 3  TEASER         2             NaN           4       speech   PICARD V.O.
# 4  TEASER         3             NaN           5  description           NaN
#
#                                                 text  speechdescription  \
# 0   The U.S.S. Enterprise NCC 1701-D traveling at...              False
# 1   Captain's log, stardate 42353.7. Our destinat...              False
# 2         on the gigantic new Enterprise NCC 1701-D.              False
# 3   My orders are to examine Farpoint, a starbase...              False
# 4   Huge, with a giant wall diagram showing the i...              False
#
#      Released  Episode  imdbRating     imdbID  Season
# 0  1987-09-26      1.0         6.9  tt0094030     1.0
# 1  1987-09-26      1.0         6.9  tt0094030     1.0
# 2  1987-09-26      1.0         6.9  tt0094030     1.0
# 3  1987-09-26      1.0         6.9  tt0094030     1.0
# 4  1987-09-26      1.0         6.9  tt0094030     1.0

# %% [markdown]
# Since we are working specifically with the text data for our goal, we need to filter the dataset to only the lines where there is actually speech being said, rather than a scene description.

# %%
# filtered to only rows where a charactor spoke in the episode
startrekspeech = startrek_data.loc[startrek_data['type'] == 'speech']

# take a look
startrekspeech.head(10)
# Out:
#     Unnamed: 0                episode productionnumber setnames characters  \
# 1            2  encounter at farpoint              NaN      NaN        NaN
# 3            4  encounter at farpoint              NaN      NaN        NaN
# 5            6  encounter at farpoint              NaN      NaN        NaN
# 7            8  encounter at farpoint              NaN      NaN        NaN
# 9           10  encounter at farpoint              NaN      NaN        NaN
# 12          13  encounter at farpoint              NaN      NaN        NaN
# 13          14  encounter at farpoint              NaN      NaN        NaN
# 14          15  encounter at farpoint              NaN      NaN        NaN
# 15          16  encounter at farpoint              NaN      NaN        NaN
# 16          17  encounter at farpoint              NaN      NaN        NaN
#
#        act scenenumber  scenedetails  partnumber    type           who  \
# 1   TEASER         1             NaN           2  speech   PICARD V.O.
# 3   TEASER         2             NaN           4  speech   PICARD V.O.
# 5   TEASER         3             NaN           6  speech   PICARD V.O.
# 7   TEASER         4             NaN           8  speech   PICARD V.O.
# 9   TEASER         5             NaN          10  speech   PICARD V.O.
# 12  TEASER         7             NaN          13  speech        PICARD
# 13  TEASER         7             NaN          14  speech          DATA
# 14  TEASER         7             NaN          15  speech        PICARD
# 15  TEASER         7             NaN          16  speech          TROI
# 16  TEASER         7             NaN          17  speech        PICARD
#
#                                                  text  speechdescription  \
# 1    Captain's log, stardate 42353.7. Our destinat...              False
# 3    My orders are to examine Farpoint, a starbase...              False
# 5    acquainted with my new command, this Galaxy C...               True
# 7    I am still somewhat in awe of its size and co...              False
# 9             several key positions, most notably ...               True
# 12   You will agree, Data, that Starfleet's instru...              False
# 13   Difficult ... how so? Simply solve the myster...              False
# 14                                 As simple as that.               True
# 15   Farpoint Station. Even the name sounds myster...              False
# 16   The problem, Data, is that another life form ...              False
#
#       Released  Episode  imdbRating     imdbID  Season
# 1   1987-09-26      1.0         6.9  tt0094030     1.0
# 3   1987-09-26      1.0         6.9  tt0094030     1.0
# 5   1987-09-26      1.0         6.9  tt0094030     1.0
# 7   1987-09-26      1.0         6.9  tt0094030     1.0
# 9   1987-09-26      1.0         6.9  tt0094030     1.0
# 12  1987-09-26      1.0         6.9  tt0094030     1.0
# 13  1987-09-26      1.0         6.9  tt0094030     1.0
# 14  1987-09-26      1.0         6.9  tt0094030     1.0
# 15  1987-09-26      1.0         6.9  tt0094030     1.0
# 16  1987-09-26      1.0         6.9  tt0094030     1.0

# %%
# take a look at the types 
startrekspeech.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 68487 entries, 1 to 110173
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         68487 non-null  int64
#  1   episode            68487 non-null  object
#  2   productionnumber   67797 non-null  object
#  3   setnames           61980 non-null  object
#  4   characters         62339 non-null  object
#  5   act                68487 non-null  object
#  6   scenenumber        68487 non-null  object
#  7   scenedetails       0 non-null      float64
#  8   partnumber         68487 non-null  int64
#  9   type               68487 non-null  object
#  10  who                68486 non-null  object
#  11  text               68487 non-null  object
#  12  speechdescription  68487 non-null  bool
#  13  Released           67739 non-null  object
#  14  Episode            67739 non-null  float64
#  15  imdbRating         67739 non-null  float64
#  16  imdbID             67739 non-null  object
#  17  Season             67739 non-null  float64
# dtypes: bool(1), float64(4), int64(2), object(11)
# memory usage: 9.5+ MB

# %% [markdown]
# ### Data Dictionary
#
# Filtering the data to only the spoken parts reduced the dataset to 62% of the original size. Now we're going to drop some columns as some of them are not relevant to our needs, as most of this information is related to the production of the show.
#
# We'll be dropping:
# - `Unnamed: 0` : this is a column that showed the order of the dialogue spoken, since we already filtered the set for speech, this is no longer needed.
# - `productionnumber` : the production number of the episode
# - `setnames` : the names of the set
# - `characters` : a list of characters that appear in the episode
# - `act` : the act number within the episode
# - `scenenumber` : the scene number within the act of the episode
# - `scenedetails` : the details of a particular scene within the episode
# - `partnumber` : the part number of the scene within the act of an episode
# - `type` : contained either 'speech' or 'description', since we already filtered for speech, we can drop this column
# - `speechdescription`: shows if the speech contained a speech description for the particular line (which we can clean out)
# - `imdbID`: the ID number of the imdb rating
#
# We'll be keeping:
# - `episode` : this shows the name of the episode
# - `Episode` : the episode number
# - `Season` : the season number
# - `who` : the character name(s)
# - `Released`: date of release for the episode in the line
# - `text` : the line spoken by the character(s) for the row
# - `imdbRating` : the target variable, our imdb rating
#
# We're going to create our new dataframe that we'll working with. After it's creation, we'll check for missing/null or duplicated values.

# %%
# create a new dataframe with these filtered columns
StarTrek_df = startrekspeech.filter(['episode', 'Episode', 'Season', 'Released', 'who', 'text', 'imdbRating'], axis=1)

#sanity check
StarTrek_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 68487 entries, 1 to 110173
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   episode     68487 non-null  object
#  1   Episode     67739 non-null  float64
#  2   Season      67739 non-null  float64
#  3   Released    67739 non-null  object
#  4   who         68486 non-null  object
#  5   text        68487 non-null  object
#  6   imdbRating  67739 non-null  float64
# dtypes: float64(3), object(4)
# memory usage: 4.2+ MB

# %% [markdown]
# #### Missing Values and Duplicated Rows
#
# Now we'll begin looking into missing values and any potential duplicate rows.

# %%
# check for null/missing values
StarTrek_df.isna().sum()
# Out:
# episode         0
# Episode       748
# Season        748
# Released      748
# who             1
# text            0
# imdbRating    748
# dtype: int64

# %% [markdown]
# There are 748 missing values across the rows, as well as one missing character. Let's double check for duplicates before we start handling this.

# %%
#print the total number of duplicated rows
print(f"There are {StarTrek_df.duplicated().sum()} duplicate rows")
# Out:
# There are 854 duplicate rows

# %% [markdown]
# There are 854 duplicate rows, let's take a look to make sure that they are *actually* duplicated rows.

# %%
# show duplicate rows
StarTrek_df.loc[StarTrek_df.duplicated(keep=False), :]
# Out:
#                       episode  Episode  Season    Released      who  \
# 95      encounter at farpoint      1.0     1.0  1987-09-26     WORF
# 156     encounter at farpoint      1.0     1.0  1987-09-26     WORF
# 455     encounter at farpoint      1.0     1.0  1987-09-26    RIKER
# 515     encounter at farpoint      1.0     1.0  1987-09-26    RIKER
# 1191            the naked now      2.0     1.0  1987-10-03   PICARD
# ...                       ...      ...     ...         ...      ...
# 109920     all good things...     25.0     7.0  1994-05-23   PICARD
# 109975     all good things...     25.0     7.0  1994-05-23     DATA
# 110029     all good things...     25.0     7.0  1994-05-23     DATA
# 110106     all good things...     25.0     7.0  1994-05-23   PICARD
# 110126     all good things...     25.0     7.0  1994-05-23     WORF
#
#                     text  imdbRating
# 95             Aye, sir.         6.9
# 156            Aye, sir.         6.9
# 455                 Sir?         6.9
# 515                 Sir?         6.9
# 1191        Picard here.         6.5
# ...                  ...         ...
# 109920        Thank you.         8.5
# 109975         Aye, sir.         8.5
# 110029         Yes, sir.         8.5
# 110106        Thank you.         8.5
# 110126   Stardate 47988.         8.5
#
# [1534 rows x 7 columns]

# %% [markdown]
# We can confirm that they are indeed duplicated, which leads us to the next step, dropping the duplicate values.
#
# We'll use`drop_duplicates()` on the original data, then we'll assign a new index using `reset_index()`. If we don't do this, the index will be missing values as a result of the drop, which doesn't help us in the future - as we have to maintain a defined index for ease of exploring.

# %%
# dropping the duplicate rows in place
StarTrek_df.drop_duplicates(inplace=True)

# %%
# reseting the index 
StarTrek_df.reset_index(inplace=True, drop=True)

# %%
# quick look again
StarTrek_df.head()
# Out:
#                  episode  Episode  Season    Released           who  \
# 0  encounter at farpoint      1.0     1.0  1987-09-26   PICARD V.O.
# 1  encounter at farpoint      1.0     1.0  1987-09-26   PICARD V.O.
# 2  encounter at farpoint      1.0     1.0  1987-09-26   PICARD V.O.
# 3  encounter at farpoint      1.0     1.0  1987-09-26   PICARD V.O.
# 4  encounter at farpoint      1.0     1.0  1987-09-26   PICARD V.O.
#
#                                                 text  imdbRating
# 0   Captain's log, stardate 42353.7. Our destinat...         6.9
# 1   My orders are to examine Farpoint, a starbase...         6.9
# 2   acquainted with my new command, this Galaxy C...         6.9
# 3   I am still somewhat in awe of its size and co...         6.9
# 4            several key positions, most notably ...         6.9

# %% [markdown]
# Now that we've dropped our duplicate rows, let's take another look at the missing values once more.

# %%
# show null rows
StarTrek_df[StarTrek_df.isna().any(axis=1)]
# Out:
#                   episode  Episode  Season    Released             who  \
# 47876        time's arrow      NaN     NaN         NaN   PICARD (V.O.)
# 47877        time's arrow      NaN     NaN         NaN   PICARD (V.O.)
# 47878        time's arrow      NaN     NaN         NaN       SCIENTIST
# 47879        time's arrow      NaN     NaN         NaN          PICARD
# 47880        time's arrow      NaN     NaN         NaN            DATA
# ...                   ...      ...     ...         ...             ...
# 50873             rascals      NaN     NaN         NaN          GUINAN
# 50874             rascals      NaN     NaN         NaN        YOUNG RO
# 50875             rascals      NaN     NaN         NaN        YOUNG RO
# 50876             rascals      NaN     NaN         NaN          GUINAN
# 54117  birthright: part 2     17.0     6.0  1993-02-27             NaN
#
#                                                     text  imdbRating
# 47876   Captain's log, stardate 45959.1. The Enterpri...         NaN
# 47877   All we've been told is that evidence has been...         NaN
# 47878   Work crews were down here installing seismic ...         NaN
# 47879   And it's been determined that they date back ...         NaN
# 47880   The biofocal vision aide is typical of the er...         NaN
# ...                                                  ...         ...
# 50873                              Only if you're ready.         NaN
# 50874   It's not quite as bad as I remembered it... b...         NaN
# 50875                               We better get going.         NaN
# 50876   There's no hurry. The Transporter will still ...         NaN
# 54117   van'aj javDIch Qong DIr Sa'VIch ghIH yot quel...         7.3
#
# [741 rows x 7 columns]

# %% [markdown]
# ##### Imputing Missing Values
#
# We can see that there are missing values for `Episode`, `Season`, `Released`, and `imdbRating`. We're going to plug in these values manually, as this information is easily found [here](https://www.imdb.com/title/tt0708828/) (which is specifically for one episode, "time's arrow"). We're going to look up specifically for the one episode, "Time's Arrow", and input values.

# %%
# plug in episode, season, Released and imdbRating manually 

#looking up one episode
StarTrek_df.loc[StarTrek_df['episode'] == "time's arrow"]
# Out:
#             episode  Episode  Season Released             who  \
# 47876  time's arrow      NaN     NaN      NaN   PICARD (V.O.)
# 47877  time's arrow      NaN     NaN      NaN   PICARD (V.O.)
# 47878  time's arrow      NaN     NaN      NaN       SCIENTIST
# 47879  time's arrow      NaN     NaN      NaN          PICARD
# 47880  time's arrow      NaN     NaN      NaN            DATA
# ...             ...      ...     ...      ...             ...
# 48270  time's arrow      NaN     NaN      NaN         BEVERLY
# 48271  time's arrow      NaN     NaN      NaN          PICARD
# 48272  time's arrow      NaN     NaN      NaN            TROI
# 48273  time's arrow      NaN     NaN      NaN           RIKER
# 48274  time's arrow      NaN     NaN      NaN            TROI
#
#                                                     text  imdbRating
# 47876   Captain's log, stardate 45959.1. The Enterpri...         NaN
# 47877   All we've been told is that evidence has been...         NaN
# 47878   Work crews were down here installing seismic ...         NaN
# 47879   And it's been determined that they date back ...         NaN
# 47880   The biofocal vision aide is typical of the er...         NaN
# ...                                                  ...         ...
# 48270   These strands appear to be biomagnetic... var...         NaN
# 48271                                   A life-form... ?         NaN
# 48272   No. There is no life here... what I have sens...         NaN
# 48273   My God... they're delivering more of them... ...         NaN
# 48274                Will, look at what he's carrying...         NaN
#
# [399 rows x 7 columns]

# %%
# plug in values manually (episode: time's arrow)
StarTrek_df.at[47876:48275, 'Season'] = int(5)
StarTrek_df.at[47876:48275, 'imdbRating'] = 8.4
StarTrek_df.at[47876:48275, 'Episode'] = int(26)
StarTrek_df.at[47876:48275, 'Released'] = '1995-06-14'

# %%
# sanity check for the particular episode
StarTrek_df.loc[StarTrek_df['episode'] == "time's arrow"]
# Out:
#             episode  Episode  Season    Released             who  \
# 47876  time's arrow     26.0     5.0  1995-06-14   PICARD (V.O.)
# 47877  time's arrow     26.0     5.0  1995-06-14   PICARD (V.O.)
# 47878  time's arrow     26.0     5.0  1995-06-14       SCIENTIST
# 47879  time's arrow     26.0     5.0  1995-06-14          PICARD
# 47880  time's arrow     26.0     5.0  1995-06-14            DATA
# ...             ...      ...     ...         ...             ...
# 48270  time's arrow     26.0     5.0  1995-06-14         BEVERLY
# 48271  time's arrow     26.0     5.0  1995-06-14          PICARD
# 48272  time's arrow     26.0     5.0  1995-06-14            TROI
# 48273  time's arrow     26.0     5.0  1995-06-14           RIKER
# 48274  time's arrow     26.0     5.0  1995-06-14            TROI
#
#                                                     text  imdbRating
# 47876   Captain's log, stardate 45959.1. The Enterpri...         8.4
# 47877   All we've been told is that evidence has been...         8.4
# 47878   Work crews were down here installing seismic ...         8.4
# 47879   And it's been determined that they date back ...         8.4
# 47880   The biofocal vision aide is typical of the er...         8.4
# ...                                                  ...         ...
# 48270   These strands appear to be biomagnetic... var...         8.4
# 48271                                   A life-form... ?         8.4
# 48272   No. There is no life here... what I have sens...         8.4
# 48273   My God... they're delivering more of them... ...         8.4
# 48274                Will, look at what he's carrying...         8.4
#
# [399 rows x 7 columns]

# %% [markdown]
# We've successfully input the values for the episode, "Time's Arrow". Now we'll check for more missing values, and plug in the information accordingly.

# %%
# check for more missing values to input
StarTrek_df[StarTrek_df.isna().any(axis=1)]
# Out:
#                   episode  Episode  Season    Released             who  \
# 50536             rascals      NaN     NaN         NaN   PICARD (V.O.)
# 50537             rascals      NaN     NaN         NaN          PICARD
# 50538             rascals      NaN     NaN         NaN          GUINAN
# 50539             rascals      NaN     NaN         NaN          PICARD
# 50540             rascals      NaN     NaN         NaN          GUINAN
# ...                   ...      ...     ...         ...             ...
# 50873             rascals      NaN     NaN         NaN          GUINAN
# 50874             rascals      NaN     NaN         NaN        YOUNG RO
# 50875             rascals      NaN     NaN         NaN        YOUNG RO
# 50876             rascals      NaN     NaN         NaN          GUINAN
# 54117  birthright: part 2     17.0     6.0  1993-02-27             NaN
#
#                                                     text  imdbRating
# 50536   Captain's Log, Stardate 46235.7 Ensign Ro, Ke...         NaN
# 50537   the tertiary level of the dig. They're typica...         NaN
# 50538                                        Mmmm-hmmmm.         NaN
# 50539   Now, see these markings... they're very simil...         NaN
# 50540   So... you went to one of the most beautiful p...         NaN
# ...                                                  ...         ...
# 50873                              Only if you're ready.         NaN
# 50874   It's not quite as bad as I remembered it... b...         NaN
# 50875                               We better get going.         NaN
# 50876   There's no hurry. The Transporter will still ...         NaN
# 54117   van'aj javDIch Qong DIr Sa'VIch ghIH yot quel...         7.3
#
# [342 rows x 7 columns]

# %%
# plug in values manually (episode: Rascals)
StarTrek_df.at[50536:50877, 'Season'] = int(6)
StarTrek_df.at[50536:50877, 'imdbRating'] = 7.4
StarTrek_df.at[50536:50877, 'Episode'] = int(7)
StarTrek_df.at[50536:50877, 'Released'] = '1995-08-23'

# %%
# sanity check for the particular episode
StarTrek_df.loc[StarTrek_df['episode'] == "rascals"]
# Out:
#        episode  Episode  Season    Released             who  \
# 50536  rascals      7.0     6.0  1995-08-23   PICARD (V.O.)
# 50537  rascals      7.0     6.0  1995-08-23          PICARD
# 50538  rascals      7.0     6.0  1995-08-23          GUINAN
# 50539  rascals      7.0     6.0  1995-08-23          PICARD
# 50540  rascals      7.0     6.0  1995-08-23          GUINAN
# ...        ...      ...     ...         ...             ...
# 50872  rascals      7.0     6.0  1995-08-23        YOUNG RO
# 50873  rascals      7.0     6.0  1995-08-23          GUINAN
# 50874  rascals      7.0     6.0  1995-08-23        YOUNG RO
# 50875  rascals      7.0     6.0  1995-08-23        YOUNG RO
# 50876  rascals      7.0     6.0  1995-08-23          GUINAN
#
#                                                     text  imdbRating
# 50536   Captain's Log, Stardate 46235.7 Ensign Ro, Ke...         7.4
# 50537   the tertiary level of the dig. They're typica...         7.4
# 50538                                        Mmmm-hmmmm.         7.4
# 50539   Now, see these markings... they're very simil...         7.4
# 50540   So... you went to one of the most beautiful p...         7.4
# ...                                                  ...         ...
# 50872                            It's my turn, isn't it?         7.4
# 50873                              Only if you're ready.         7.4
# 50874   It's not quite as bad as I remembered it... b...         7.4
# 50875                               We better get going.         7.4
# 50876   There's no hurry. The Transporter will still ...         7.4
#
# [341 rows x 7 columns]

# %%
# check for more missing values to input
StarTrek_df[StarTrek_df.isna().any(axis=1)]
# Out:
#                   episode  Episode  Season    Released  who  \
# 54117  birthright: part 2     17.0     6.0  1993-02-27  NaN
#
#                                                     text  imdbRating
# 54117   van'aj javDIch Qong DIr Sa'VIch ghIH yot quel...         7.3

# %% [markdown]
# We've successfully input the correct values for these missing episodes. There's only one row left that contains what looks like gibberish in the `text` row. We'll be dropping this row as well.

# %%
StarTrek_df.dropna(inplace=True)

# %%
# confirmed no more missing values
StarTrek_df.isna().sum()
# Out:
# episode       0
# Episode       0
# Season        0
# Released      0
# who           0
# text          0
# imdbRating    0
# dtype: int64

# %%
# sanity check
StarTrek_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67632 entries, 0 to 67632
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   episode     67632 non-null  object
#  1   Episode     67632 non-null  float64
#  2   Season      67632 non-null  float64
#  3   Released    67632 non-null  object
#  4   who         67632 non-null  object
#  5   text        67632 non-null  object
#  6   imdbRating  67632 non-null  float64
# dtypes: float64(3), object(4)
# memory usage: 4.1+ MB

# %% [markdown]
# #### Checking Dtypes of Columns
#
# There are some variables that need to be converted to their correct type. For example, the `Episode` and `Season` columns should be integers, as well as the rating `imdbRating`. In addition to that, the `Released` column is in datetime, and will be adjusted accordingly.

# %%
StarTrek_df['Episode'] = StarTrek_df['Episode'].astype('int') 
StarTrek_df['Season'] = StarTrek_df['Season'].astype('int') 
StarTrek_df['Released'] = pd.to_datetime(StarTrek_df['Released'])

StarTrek_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67632 entries, 0 to 67632
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   episode     67632 non-null  object
#  1   Episode     67632 non-null  int32
#  2   Season      67632 non-null  int32
#  3   Released    67632 non-null  datetime64[ns]
#  4   who         67632 non-null  object
#  5   text        67632 non-null  object
#  6   imdbRating  67632 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int32(2), object(3)
# memory usage: 3.6+ MB

# %% [markdown]
# In order to work with the `imdbRating` column for our future models, we'll convert this column to an integer in order to prepare it for preprocessing.

# %%
# rounding the imdb rating to ensure accuracy of the data
StarTrek_df['imdbRating'] = round(StarTrek_df['imdbRating'])

# assigning the imdb column to integer
StarTrek_df['imdbRating'] = StarTrek_df['imdbRating'].astype('int') 

# sanity check
StarTrek_df.head()
# Out:
#                  episode  Episode  Season   Released           who  \
# 0  encounter at farpoint        1       1 1987-09-26   PICARD V.O.
# 1  encounter at farpoint        1       1 1987-09-26   PICARD V.O.
# 2  encounter at farpoint        1       1 1987-09-26   PICARD V.O.
# 3  encounter at farpoint        1       1 1987-09-26   PICARD V.O.
# 4  encounter at farpoint        1       1 1987-09-26   PICARD V.O.
#
#                                                 text  imdbRating
# 0   Captain's log, stardate 42353.7. Our destinat...           7
# 1   My orders are to examine Farpoint, a starbase...           7
# 2   acquainted with my new command, this Galaxy C...           7
# 3   I am still somewhat in awe of its size and co...           7
# 4            several key positions, most notably ...           7

# %% [markdown]
# ### Text Data Cleaning
#
# We can see that within the `who` column that there are character names that come as one name, or paired together with a voiceover (V.O.), on-screen (O.S), or paired with another character.
#
# We'll be following a generalized NLP workflow:
#
# 1. Tokenization + Remove Pronouciation
# 2. Remove Stop Words
# 3. Lemmatization or Stemming
#
# So we're cleaning this column so that it's only the first name that appears.

# %%
# taking a closer look at the unique values of the who column
StarTrek_df['who'].unique().tolist()
# Out:
# [' PICARD V.O.',
#  ' PICARD',
#  ' DATA',
#  ' TROI',
#  ' WORF',
#  ' CONN',
#  ' "Q" (ELIZABETHAN)',
#  ' MEDIC',
#  ' "Q" (MARINE CAPTAIN)',
#  ' PICARD "Q" (MARINE CAPTAIN) PICARD "Q" (MARINE CAPTAIN)',
#  ' "Q" (21ST CENTURY)',
#  ' TASHA',
#  ' PICARD TROI',
#  " PICARD'S INTERCOM VOICE",
#  ' MANDARIN-BAILIFF',
#  ' FUTURE MILITARY OFFICER',
#  ' MILITARY OFFICER',
#  ' "Q" (JUDGE)',
#  ' "Q" (JUDGE) MANDARIN-BAILIFF',
#  ' DATA "Q" (JUDGE)',
#  ' OPS',
#  " RIKER'S VOICE",
#  ' ZORN',
#  ' RIKER',
#  " ZORN ZORN (Cont'd)",
#  ' WESLEY',
#  ' BEVERLY',
#  ' MARKHAM',
#  ' GEORDI/MARKHAM',
#  ' GEORDI',
#  ' BANDI WOMAN',
#  " DATA'S VOICE",
#  ' RIKER (V.O.)',
#  ' ADMIRAL',
#  " PICARD'S VOICE",
#  ' PICARD WORF',
#  " TROI'S VOICE",
#  ' PICARD ZORN',
#  ' YOUNG ENSIGN',
#  ' COMPUTER VOICE',
#  ' RIKER COMPUTER VOICE',
#  ' RIKER DATA',
#  " WESLEY'S VOICE",
#  ' PICARD WES',
#  ' BEVERLY WESLEY',
#  " TASHA'S VOICE",
#  ' WES',
#  ' SECURITY VOICE',
#  " ZORN'S VOICE",
#  ' SECURITY POSITION',
#  ' OPERATIONS POSITION',
#  " ZORN'S VOICE PICARD",
#  ' INTERCOM VOICE',
#  ' "Q" (STARFLEET)',
#  ' PICARD RIKER',
#  ' PICARD TASHA',
#  ' PICARD (V.O.)',
#  " WOMAN'S COM VOICE",
#  ' TRANSPORTER CHIEF',
#  " TASHA'S COM VOICE",
#  " RIKER'S COM VOICE",
#  " BEVERLY'S COM VOICE",
#  ' PICARD (V. O.)',
#  " TROI'S COM VOICE",
#  ' WESLEY (V.O)',
#  " PICARD'S COM VOICE",
#  ' DATA (V.O.)',
#  ' SHIMODA',
#  ' MACDOUGAL',
#  " WESLEY'S COM VOICE",
#  ' PICARD (V.O)',
#  ' SECURITY COM VOICE',
#  " PICARD PICARD (Cont'd)",
#  ' CREWMAN',
#  " WORF'S COM VOICE",
#  " MACDOUGAL'S COM VOICE",
#  ' LUTAN',
#  ' HAGON',
#  ' DATA PICARD',
#  ' DATA (O.S.)',
#  ' BEVERLY (O.S.)',
#  ' YAREENA (O.S.)',
#  ' TASHA YAREENA',
#  ' YAREENA',
#  " DATA DATA (Cont'd)",
#  ' DATA GEORDI',
#  " TRANSPORTER CHIEF'S COM VOICE",
#  ' DATA PICARD TROI',
#  ' TRANSPORTER CHIEF (V.O.)',
#  ' GEORDI (V.O.)',
#  ' FACE',
#  ' TROI RIKER',
#  ' STEVEN',
#  ' VICTORIA',
#  ' TROI VICTORIA',
#  ' WYATT',
#  ' MRS. TROI',
#  ' MRS. TROI TELEPATHIC V.O.',
#  ' TROI TELEPATHIC V.O.',
#  ' VALEDA',
#  ' PICARD (V.O.) RIKER',
#  ' RIKER PICARD',
#  ' WYATT (V.O.)',
#  " PICARD'S (V.O.)",
#  ' WRENN',
#  ' ARIANA',
#  ' HOMN',
#  ' MRS. TROI TELEPATHIC V. O.',
#  ' KOSINSKI',
#  ' ARGYLE',
#  ' ASSISTANT',
#  " GEORDI'S COM VOICE",
#  ' PICARD DATA',
#  ' PICARD (V.O.',
#  ' KOSINSKI PICARD',
#  ' FIRST CREWMEMBER',
#  ' MOTHER PICARD',
#  ' TRAVELER',
#  ' TRAVELER PICARD',
#  ' CREWMEMBER',
#  " TROI RIKER'S COM VOICE",
#  ' WORF (V.O.)',
#  " TAAR'S COM VOICE",
#  ' TAAR (V.O.)',
#  ' TAAR',
#  ' RIKER (V.O) DATA (V.O.)',
#  ' RIKER/DATA (V.O)',
#  ' TROI PICARD',
#  ' LETEK',
#  ' MORDOC',
#  ' LETEK RIKER (V.O.)',
#  ' RIKER LETEK',
#  ' TASHA (V. O.)',
#  ' KYRON',
#  ' PORTAL FIGURE',
#  ' PORTAL',
#  ' RIKER GEORDI',
#  ' KAYRON',
#  ' TASHA RIKER',
#  ' PORTAL RIKER',
#  ' SSESTAR',
#  ' TASHA DATA',
#  ' GEORDI PICARD',
#  " BADAR N'D'D",
#  " SINGH'S COM VOICE",
#  ' SINGH',
#  ' RIKER AND TASHA',
#  ' DATA TASHA',
#  ' FIRST SECURITY GUARD',
#  ' RIKER)',
#  ' PICARD)',
#  ' RIKER (O.S.)',
#  ' TROI (O.S.)',
#  ' WESLEY)',
#  ' RIVAN',
#  ' LIATOR',
#  ' RIVAN WORF',
#  ' FIRST EDO CITIZEN',
#  ' FIRST EDO BOY',
#  ' EDO GIRL',
#  ' GEORDI TASHA',
#  ' DATA CONN CREWMEMBER',
#  ' CONN CREWMEMBER PICARD',
#  ' CONN CREWMEMBER',
#  ' EDOLORD (V.O.)',
#  ' WESLEY EDO GIRL',
#  ' RIVAN TASHA',
#  ' SECOND EDO BOY',
#  ' FIRST MEDIATOR',
#  ' SECOND MEDIATOR',
#  ' WESLEY MEDIATOR',
#  " TASHA'S COM VOICE GEORDI",
#  " PICARD (V.O.) PICARD (Cont'd)",
#  ' EDOLORD (V. O.)',
#  ' MEDICAL TECHNICIAN',
#  ' DATA BEVERLY',
#  ' RIVAN (O.S.)',
#  ' WESLEY (O.S.)',
#  ' BOK',
#  ' KAZAGO',
#  ' RATA',
#  ' PICARD BOK',
#  ' VOICES (V.O.)',
#  " PICARD'S RECORDED VOICE",
#  ' VOICES (V. O.)',
#  " WESLEY WESLEY (Cont'd)",
#  ' RIKER TROI',
#  ' COMPUTER',
#  ' BOK (O.S.)',
#  ' RIKER (V.O.) TASHA',
#  ' FIRST VOICE (V.O.)',
#  ' SECOND VOICE (V.O.)',
#  ' THIRD VOICE (V.O.)',
#  ' "Q" (V.O.)',
#  ' "Q" (ADMIRAL)',
#  ' GEORDI DATA',
#  ' "Q" (MARSHAL)',
#  ' RIKER "Q" (MARSHAL)',
#  ' TASHA (O.S.)',
#  ' "Q" (MARSHAL) (O.S.)',
#  ' "Q" (MARSHAL) "Q" (Cont\'d)',
#  ' "Q" (MARSHAL) PICARD',
#  ' "Q". (MARSHAL)',
#  ' "Q" (DATA)',
#  " ENGINEER'S COM VOICE",
#  ' "Q" (O.S.)',
#  ' "Q" (COMMANDER)',
#  ' RIKER "Q" (COMMANDER)',
#  ' "Q" (COMMANDER) "Q" (Cont\'d)',
#  " DATA'S COM VOICE",
#  ' WOMAN',
#  ' "Q" (BROTHER) (O.S.)',
#  ' "Q" (BROTHER)',
#  ' DATA RIKER',
#  ' WESLEY RIKER',
#  ' JAMESON',
#  ' KARNAS',
#  ' KARNAS (V.O.)',
#  ' JAMESON (V.O.)',
#  ' ANNE JAMESON',
#  ' ANNE',
#  ' ANNE (V.O.)',
#  ' JAMESON (O.S.)',
#  ' ANNE TROI',
#  ' JAMESON PICARD',
#  ' JAMESON (BOY)',
#  ' PICARD (O.S.)',
#  ' PICARD COMPUTER VOICE',
#  ' SECRETARY',
#  ' JESSICA',
#  ' LEECH',
#  ' WHALEN',
#  ' VENDOR',
#  ' VENDOR PICARD',
#  ' BELL (O.S.)',
#  ' BELL',
#  ' MCNARY',
#  " JARADAN'S COM VOICE",
#  " JARADAN'S COM VOICE RIKER",
#  " JARALAN'S COM VOICE",
#  ' BELL PICARD',
#  ' McNARY',
#  ' SERGEANT',
#  ' SERGANT',
#  ' REDBLOCK',
#  ' THUG',
#  " GEORDI RIKER'S COM VOICE",
#  ' REDBLOCK DATA',
#  ' DATA (O. S.)',
#  ' ARGYLE (O.S.)',
#  ' LORE',
#  ' LORE WESLEY',
#  " LORE LORE (Cont'd)",
#  ' WORF DATA',
#  ' WESLEY PICARD',
#  ' LORE (O.S.) LORE',
#  ' LORE (O.S.)',
#  ' PICARD WESLEY',
#  " FEMALE'S COM VOICE",
#  " BEATA'S COM VOICE",
#  ' BEATA',
#  ' TRENT',
#  ' ARIEL',
#  ' RAMSEY',
#  ' PICARD GEORDI',
#  " ENGINEERING'S COM VOICE",
#  " RAMSEY RAMSEY (Cont'd)",
#  ' QUINTEROS',
#  ' BYNAR ONE ZERO',
#  ' BYNAR ZERO ONE PICARD',
#  ' ZERO ONE',
#  ' ONE ZERO PICARD',
#  ' ONE ZERO ZERO ONE ONE ZERO',
#  ' ZERO ONE ONE ZERO QUINTEROS',
#  ' ONE ZERO',
#  ' GEORDI (O.S.)',
#  ' ZERO ZERO',
#  ' ONE ONE ZERO ZERO ONE ONE ZERO ZERO ONE ONE RIKER',
#  ' ONE ONE',
#  ' ZERO ZERO (SUBTITLED)',
#  ' ONE ONE (SUBTITLED)',
#  ' ONE ONE RIKER',
#  ' MINUET',
#  ' ONE ZERO WESLEY',
#  ' ONE ZERO ZERO ONE',
#  ' ONE ZERO ZERO ONE ONE ZERO WESLEY',
#  ' ZERO ONE WESLEY',
#  ' BASS',
#  ' DRUMMER',
#  ' PIANIST',
#  ' STARBASE COMPUTER (V.O.)',
#  ' AD LIBBED VOICES',
#  ' STARBASE COM VOICE',
#  ' QUINTEROS (O.S.)',
#  ' MINUET RIKER',
#  ' QUINTEROS DATA',
#  ' COMPUTER (V.O.)',
#  ' ZERO ONE ONE ZERO ZERO ONE',
#  ' ONE ZERO ZERO ZERO ONE ONE ZERO ZERO ONE ONE PICARD',
#  ' ONE ZERO RIKER',
#  ' ONE ONE PICARD',
#  ' MANDL',
#  ' LUISA',
#  ' BENSON',
#  ' BENSEN',
#  ' MALENCON',
#  " BENSEN'S COM VOICE",
#  ' BEVERLY COMPUTER VOICE',
#  " BENSEN RIKER'S COM VOICE",
#  ' FEMALE COM VOICE',
#  ' ENGINEER',
#  ' TRANSLATOR VOICE',
#  " TRANSPORTER CHIEF'S COM VOICE RIKER",
#  ' HARRY',
#  ' DR. BERNARD',
#  ' RASHELLA',
#  ' RADUE',
#  " RADUE'S COM VOICE",
#  ' PICARD RADUE',
#  ' KATIE',
#  ' DUANA',
#  ' ALEXANDRA',
#  ' TOYA',
#  ' LEDA',
#  ' ACCOLAN',
#  ' MELIAN',
#  ' DUANE',
#  ' CUSTODIAN VOICE',
#  ' WESLEY DUANA',
#  ' DUANA WESLEY DUANA',
#  ' HARRY PICARD',
#  " PICARD TASHA'S COM VOICE",
#  ' QUINN',
#  ' REMMICK',
#  ' OLIANA',
#  " T'SHANIK",
#  ' MORDOCK',
#  ' CHANG',
#  ' TASHA PICARD',
#  ' JAKE',
#  ' JAKE (V.O.)',
#  ' RONDON',
#  " REMMICK'S COM VOICE",
#  ' TECHNICIAN #1 (V.O.)',
#  ' COMPUTER VOICE (V.O.)',
#  ' TECHNICIAN #1',
#  ' TECHNICIAN #2',
#  ' CHANG.',
#  ' KORRIS',
#  ' KONMEL',
#  ' NURSE',
#  ' KONMEL KORRIS',
#  " K'NERA",
#  ' GUARD',
#  " THE PEDDLER'S COM VOICE",
#  ' SOLIS',
#  ' RICE (O.S.)',
#  ' RICE',
#  ' PICARD SOLIS',
#  ' PICARD BEVERLY',
#  ' GEORDI (V. O.)',
#  ' LOGAN',
#  ' LIAN',
#  " LOGAN'S COM VOICE",
#  ' THE PEDDLER',
#  ' PEDDLER',
#  " BEN'S COM VOICE PICARD",
#  " BEN'S COM VOICE",
#  ' LYNCH',
#  " LYNCH'S COM VOICE",
#  " TROI'S COM VOICE BEN'S COM VOICE",
#  ' PICARD LYNCH',
#  ' ARMUS',
#  ' RIKER ARMUS',
#  ' ARMUS (O.S.)',
#  ' ARMUS (O.S.) TROI',
#  ' TROI BEVERLY',
#  " TASHA TASHA (Cont'd)",
#  ' VOICE (V.O.)',
#  " T'JON (V.O.)",
#  ' SOBI (V.O.)',
#  ' LANGOR (V.O.)',
#  " T'JON'S COM VOICE",
#  " PICARD T'JON'S COM VOICE",
#  " TASHA T'JON'S COM VOICE",
#  ' RIKER TASHA',
#  " T'JON",
#  ' ROMAS',
#  ' SOBI',
#  ' LANGOR',
#  " SOBI T'JON",
#  " ROMAS T'JON",
#  " T'Jon",
#  ' MARGAN',
#  " MANHEIM'S COM VOICE",
#  ' EDOUARD',
#  ' FRANCINE',
#  ' GABRIELLE',
#  ' LAURA (V.O.)',
#  ' LAURA',
#  ' MANHEIM',
#  ' WORF PICARD',
#  ' PAUL',
#  " MANHEIM'S",
#  ' LAURA (O.S.)',
#  " LAURA (Cont'd)",
#  ' KEEL',
#  ' KEEL (O.S.)',
#  ' BOLIAN',
#  ' RIXX',
#  ' TRYLA',
#  ' SAVAR',
#  ' AARON',
#  ' PICARD SAVAR',
#  ' QUINN (O.S.)',
#  ' PICARD RIKER PICARD',
#  ' BEVERLY GEORDI',
#  ' PICARD AARON',
#  ' DATA WORF',
#  ' RALPH',
#  ' SONNY',
#  ' CLARE',
#  " RALPH'S COM VOICE",
#  ' RALPH PICARD',
#  ' TEBOK',
#  ' THEI',
#  ' REPULSE VOICE',
#  ' SICKBAY VOICE',
#  ' GUINAN',
#  ' PULASKI',
#  " PULASKI PULASKI (Cont'd) RIKER",
#  ' HESTER',
#  " PULASKI PICARD'S COM VOICE",
#  ' PULASKI TROI',
#  ' IAN',
#  " PULASKI'S COM VOICE",
#  ' PULASKI DATA',
#  ' MISS GLADSTONE',
#  ' PICARD.',
#  " GEORDI PICARD'S COM VOICE",
#  ' HESTER RIKER',
#  ' WORF RIKER',
#  ' WORF (O.S.)',
#  ' HASKELL',
#  ' NAGILUM',
#  ' PICARD (V.O.) TROI',
#  ' PULASKI WORF RIKER',
#  ' COMPUTER VOICE)',
#  ' DATA COMPUTER VOICE',
#  ' ASSISTANT ENGINEER',
#  ' LESTRADE (O.S.)',
#  ' LESTRADE',
#  ' PULASKI (O.S.)',
#  ' PULASKI GEORDI',
#  ' PIE MAN',
#  ' WHORE',
#  ' PROSTITUTE (WHORE)',
#  ' PROSTITUTE',
#  ' MORIARTY',
#  ' DATA)',
#  " MORIARTY MORIARTY (Cont'd)",
#  ' GEORDI RIKER',
#  ' MORIARTY PULASKI',
#  ' RUFFIAN',
#  ' MORIARTY PICARD',
#  " OKONA'S COM VOICE",
#  ' OKONA',
#  " B.G. ROBINSON'S COM VOICE",
#  ' B.G. ROBINSON',
#  ' THE COMIC',
#  ' THE COMIC DATA',
#  ' DEBIN',
#  ' KUSHELL',
#  " OKONA OKONA (Cont'd)",
#  ' BENZAN',
#  ' HUSHELL',
#  ' YANAR',
#  ' PULASKI (V.O.)',
#  ' KAREEN',
#  " MAN'S COM VOICE",
#  ' GUINAN DATA',
#  ' PULASKI RIKER',
#  ' GRAVES (O.S.)',
#  ' GRAVES',
#  ' GRAVES KAREEN',
#  ' GRAVES DATA',
#  ' PICARD PULASKI PICARD',
#  ' KAREEN PICARD',
#  ' KAREEN (O.S.)',
#  ' KAREEN)',
#  ' WARRIOR/ADONIS',
#  ' SCHOLAR/ARTIST',
#  ' CHORUS',
#  ' SCHCLAR/ARTIST',
#  ' WOMAN GEORDI',
#  ' TROI WARRIOR/ADONIS',
#  ' RIVA',
#  " FIRST LEADER'S COM VOICE",
#  " SECOND LEADER'S COM VOICE",
#  ' SCHOLAR/ARTIST RIKER',
#  ' RIKER WARRIOR/ADONIS RIKER',
#  ' FIRST LEADER',
#  " CHIEF O'BRIEN",
#  ' MENDON',
#  ' WESLEY MENDON',
#  ' KARGAN',
#  ' MENDON PICARD',
#  ' TACTICS OFFICER',
#  ' KLAG',
#  ' VEKMA',
#  " CAPTAIN KARGAN'S COM VOICE",
#  " O'BRIEN",
#  ' PHILLIPA',
#  ' NAKAMURA',
#  ' MADDOX',
#  ' PICARD PHILLIPA',
#  ' PICARD MADDOX',
#  ' PICARD/RIKER',
#  ' MADDOX PHILLIPA',
#  ' GIBSON',
#  ' ANYA',
#  ' SALIA',
#  ' WESLEY GEORDI',
#  " SALIA'S COM VOICE",
#  ' TEENAGE GIRL',
#  ' RIKER GUINAN',
#  ' ARON',
#  " ANYA'S COM VOICE",
#  ' SALIA WESLEY',
#  ' ANYA (O.S.)',
#  ' GIBSON PICARD',
#  ' WESLEY SALIA (O.S.)',
#  ' VOICE',
#  ' VARLEY',
#  ' TARIS',
#  ' DOCTOR',
#  " O'BRIEN PICARD",
#  " O'BRIEN'S COM VOICE",
#  ' WILLIAMS',
#  ' BELLBOY',
#  ' ASSISTANT MANAGER',
#  ' TEXAS',
#  ' VANESSA',
#  ' DEALER',
#  " RIKER'S COM VOICE PICARD",
#  " RIKER RIKER (Cont'd)",
#  ' MIKEY D',
#  ' CROUPIER (O.S.)',
#  ' CROUPIER',
#  ' TEXAS (O.S.)',
#  ' ASSISTANT MANAGER (O.S.)',
#  " RIKER PICARD'S COM VOICE",
#  ' TROI PULASKI',
#  ' P2',
#  ' RIKER PULASKI',
#  " HERBERT'S COM VOICE",
#  ' HERBERT',
#  ' KYLE',
#  ' KYLE PULASKI',
#  ' TROI WORF',
#  " KYLE KYLE (Cont'd)",
#  ' RIKER WESLEY',
#  ' DAVIES',
#  ' SARJENKA (V.O.)',
#  ' PULASKI PULASKI',
#  ' HILDEBRANT',
#  ' ALANS',
#  ' ALANS HILDEBRANT',
#  ' SARJENKA',
#  ' SONYA',
#  ' SONYA PICARD',
#  ' SONYA GEORDI',
#  ' Q',
#  ' SONYA (O.S.)',
#  ' GEORDI (O.S).',
#  ' Q PICARD',
#  ' Q PICARD Q',
#  ' PICARD Q',
#  ' RIKER Q',
#  ' Q Q',
#  ' WESLEY COM VOICE',
#  ' DATA COM VOICE',
#  ' WORF COM VOICE',
#  ' BORG',
#  ' Q (O.S.)',
#  ' GEORGI',
#  ' PICARD COM VOICE',
#  ' GEORDI COM VOICE',
#  ' Q WORF',
#  ' GREBNEDLOG',
#  ' REGINOD',
#  ' SURGEON',
#  " GEORDI GEORDI (Cont'd)",
#  ' BIOMOLECULAR PHYSIOLOGIST',
#  ' COMPUTER (V.O) RIKER',
#  ' REGINOD GEBNEDLOG',
#  ' COMPUTER VOICE RIKER',
#  ' DANILO',
#  ' BRENNA',
#  ' DANILO BRENNA (V.O.)',
#  ' OLD MAN',
#  ' BRENNA (V.O.) DANILO',
#  ' GRANGER',
#  ' GRANGER 1B',
#  " DANILO DANILO (Cont'd)",
#  ' BRENNA PICARD',
#  " BRENNA BRENNA (Cont'd)",
#  ' TRANSPORT PILOT',
#  ' TRANSPORT PILOT MRS. TROI (V.O.)',
#  ' MRS. TROI (V.O.)',
#  " MRS. TROI MRS. TROI (Cont'd)",
#  ' MRS TROI TROI',
#  " PICARD TROI TROI (Cont'd)",
#  ' SECRETARY (V.O.)',
#  ' SLADE',
#  " PICARD (CONT'D)",
#  ' TOUGHGUY',
#  ' REX',
#  ' PULASKI COM VOICE',
#  ' MRS. TROI (O.S.)',
#  ' SLADE REX',
#  ' PICARD SLADE',
#  ' ANTEDIANS',
#  ' ANTEDIAN FEMALE',
#  " PULASKI (cont'd)",
#  ' CLANCEY',
#  " PICARD (cont'd)",
#  ' ADMIRAL GROMEK',
#  " ADMIRAL GROMEK (cont'd)",
#  " K'EHLEYR",
#  " RIKER (cont'd)",
#  " K'EHLEYR (cont'd)",
#  " WORF (cont'd)",
#  " K'EHLEYR TROI",
#  " K'EHLEYR WORF",
#  " K'EHLYR",
#  " K'EHLEYR (O.S., cont'd)",
#  ' TACTICAL CREWMAN',
#  " K'TEMOC",
#  " K'TEMOC (cont'd)",
#  ' KOLRAMI',
#  " PICARD (Cont'd)",
#  ' RIKER KOLRAMI',
#  ' BURKE',
#  ' KOLRAMI PICARD',
#  ' DATA KOLRAMI',
#  ' NAGEL',
#  ' GEORDI WESLEY RIKER',
#  ' TROI DATA',
#  ' BRACTOR',
#  ' TACTICIAN',
#  ' TROI/PULASKI',
#  " O'BRIEN (cont'd)",
#  " GEORDI (cont'd)",
#  " PULASKI (V.O., cont'd)",
#  ' EDO MARBLE PLAYER',
#  ' EDO SPECTATOR',
#  ' BEATA RIKER',
#  " KARGAN KARGAN (cont'd)",
#  ' SHELIAK VOICE',
#  ' HARITATH',
#  ' KENTOR',
#  ' GOSHEVEN',
#  " DATA DATA (cont'd)",
#  " ARD'RIAN (O.S.)",
#  " ARD'RIAN",
#  ' SHELIAK',
#  " ARD'RIAN DATA",
#  " ARD'RIAN (cont'd)",
#  " DATA (cont'd)",
#  " GOSHEVEN GOSHEVEN (Cont'd)",
#  " GOSHEVEN (cont'd)",
#  " HARITATH (cont'd)",
#  ' GOSHEVEN (O.S.)',
#  ' STUBBS',
#  ' CREWMEMBER #1',
#  " CREWMEMBER#1'S COM VOICE",
#  ' ERIC',
#  ' ANNETTE',
#  ' DATA/NANITE',
#  ' KEVIN',
#  ' RISHON',
#  " TROI TROI (Cont'd)",
#  " RISHON RISHON (Cont'd)",
#  ' RISON',
#  " KEVIN KEVIN (Cont'd)",
#  ' BARRON',
#  ' LIKO',
#  ' OJI',
#  ' BARRON (O.S.)',
#  ' LIKO (O.S.)',
#  ' BEVERLY RIKER',
#  " TROI (cont'd)",
#  ' OJI (O.S.)',
#  ' OJI FENTO',
#  ' FENTO',
#  ' NURIA',
#  ' HALI (O.S.)',
#  ' HALI',
#  " LIKO'S COM VOICE",
#  ' PICARD BARRON',
#  " DATA'S COM VOICE DATA'S COM VOICE (cont'd)",
#  " LIKO (cont'd)",
#  " NURIA (cont'd)",
#  " BEVERLY (cont'd)",
#  ' TEACHER',
#  ' JEREMY',
#  ' JEREMY TROI',
#  ' WESLEY BEVERLY',
#  ' MARLA',
#  ' CHRISTY',
#  ' CHRISTY (O.S.)',
#  " GALEK SAR GALEK SAR (Cont'd)",
#  " LEAH'S VOICE",
#  ' LEAH',
#  ' GEORDI COMPUTER VOICE',
#  ' GALEK SAR (MONITOR)',
#  ' GEORDI LEAH',
#  ' PATAHK',
#  ' TOMALAK',
#  ' BOCHRA',
#  ' BEVELRY',
#  " TROI TROI (Cont'd) COMPUTER",
#  ' BHAVANI',
#  ' MENDOZA',
#  ' LEYOR',
#  ' DEVINONI',
#  ' GOSS',
#  ' ARRIDOR',
#  " ARRIDOR ARRIDOR (Cont'd)",
#  ' DEVINONI (O.S.)',
#  ' BEVERLY & TROI',
#  ' DEVINONI LEYOR',
#  ' TROI DEVINONI',
#  " DEVINONI DEVINONI (Cont'd)",
#  ' MAROUK',
#  ' MAROUK (O.S.)',
#  ' YUTA',
#  " YUTA (cont'd)",
#  ' BRULL',
#  ' YUTA (O.S.)',
#  ' VOLNOTH',
#  " VOLNOTH (cont'd)",
#  ' TEMAREK (O.S.)',
#  ' TEMAREK',
#  " BRULL (cont'd)",
#  ' YUTA RIKER',
#  ' CHORGAN',
#  ' CHORGAN (O.S.)',
#  ' CHORGAN MAROUK',
#  ' BATES',
#  ' DATA (KING HENRY)',
#  " SETAL'S COM VOICE",
#  ' SETAL',
#  ' DATA (O.C.)',
#  ' ADMIRAL HADEN',
#  " ADMIRAL HADEN ADMIRAL HADEN (Cont'd)",
#  ' JAROK',
#  ' JAROK PICARD JAROK',
#  ' NAYROK',
#  ' ZAYNAR',
#  ' RIKER WORF',
#  " O'BRIEN'S VOICE",
#  ' SECURITY MAN',
#  ' ROGA',
#  " NAYROK NAYROK (Cont'd)",
#  ' WAGNOR',
#  ' SECURITY GUARD COM VOICE',
#  ' TROI NAYROK',
#  ' NAYROCK',
#  ' POLICEMAN',
#  ' WAITER',
#  " ENGINEER'S VOICE",
#  ' FINN',
#  " FINN FINN (Cont'd)",
#  ' ALEXANA',
#  " ALEXANA (cont'd)",
#  ' FINN BEVERLY',
#  ' KATIK',
#  " FINN'S VOICE",
#  ' GARIN',
#  ' SCIENTIST',
#  ' Q TROI',
#  " Q Q (Cont'd)",
#  ' Q GEORDI',
#  ' Q2',
#  ' Q2 (V.O.)',
#  ' KRAG',
#  ' APGAR',
#  ' MANUA (O.S.)',
#  ' MANUA',
#  ' TAYNA',
#  " KRAG (cont'd)",
#  " APGAR (cont'd)",
#  " MANUA (cont'd)",
#  ' APGAR (O.S.)',
#  ' KRAG (O.S.)',
#  ' WORF GUINAN',
#  " GARRETT'S COM VOICE",
#  ' GARRETT',
#  " BEVERLY BEVERLY (Cont'd)",
#  ' GARRETT RIKER',
#  ' CASTILLO',
#  ' TASHA (com)',
#  ' COM VOICE',
#  ' KLINGON COM VOICE',
#  " GUINAN'S COM VOICE",
#  ' LAL',
#  ' ADMIRAL HAFTEL',
#  ' BALLARD',
#  ' GUINAN (O.S.)',
#  " HAFTEL ADMIRAL HAFTEL (Cont'd)",
#  ' LAL (O.S.)',
#  ' TECHNICIAN',
#  ' KURN',
#  ' GEORDI KURN',
#  ' KURN WORF',
#  " K'MPEC",
#  ' DURAS',
#  " DURAS DURAS (Cont'd)",
#  ' KAHLEST',
#  ' PICARD KAHLEST',
#  ' FALSE PICARD',
#  ' HARO',
#  " HARO (cont'd)",
#  ' THOLL (O.S.)',
#  ' THOLL',
#  " WESLEY (cont'd)",
#  " FALSE PICARD (cont'd)",
#  ' ESOQQ',
#  " DATA (Cont'd)",
#  " ESOQQ (cont'd)",
#  ' ESOQQ THOLL',
#  ' THOLL PICARD',
#  ' BEVERLY FALSE PICARD',
#  ' GEORDI TROI',
#  ' ALIEN #1',
#  ' ALIEN #2',
#  ' ALIEN #4',
#  ' PICARD ALIEN #4',
#  ' AJUR',
#  ' BORATUS',
#  ' PIKER',
#  ' PICARD & RIKER PICARD RIKER',
#  ' VASH',
#  ' JOVAL (V.O.)',
#  ' JOVAL',
#  ' PICARD JOVAL',
#  ' SOVAK',
#  ' VASH (V.O.)',
#  ' VASH PICARD AJUR',
#  ' SOVAK (O.S.)',
#  ' RIKER (COM VOICE)',
#  " VASH VASH (Cont'd)",
#  ' DESOTO',
#  ' TAM',
#  " TAM TAM (Cont'd)",
#  ' TROI PICARD TROI',
#  ' TAM TROI',
#  ' TAM TROI TAM TROI',
#  ' PICARD TAM',
#  ' ROMULAN COMMANDER',
#  " TAM'S COM VOICE",
#  " TAM (cont'd)",
#  ' HOLO-GUINAN',
#  ' BARCLAY',
#  ' HOLO-GEORDI',
#  ' HOLO-RIKER',
#  ' HOLO-TROI',
#  ' DUFFY',
#  ' GEORDI BARCLAY',
#  ' HOLO-BEVERLY',
#  ' HOLO-WESLEY',
#  ' HOLO-DATA',
#  ' HOLO-PICARD',
#  " BARCLAY BARCLAY (Cont'd)",
#  ' GEORDI GEORDI',
#  ' DATA PICARD (V.O.)',
#  ' VARRIA',
#  ' FAJO',
#  " FAJO (cont'd)",
#  " DATA'S VOICE (V.O.)",
#  " DATA'S VOICE (RECORDED)",
#  ' TOFF (O.S.)',
#  ' FAJO (O.S.)',
#  ' TOFF',
#  ' VARRIA TOFF',
#  " FAJO'S COM VOICE",
#  ' FAJO DATA',
#  ' MENDROSSEN',
#  ' SAKKATH',
#  ' SAREK',
#  ' PERRIN',
#  ' SAKKATH DATA',
#  ' SCIENCE CREWMAN',
#  " SAREK SAREK (Cont'd)",
#  ' SAREK PICARD',
#  ' SAREK (V.O.)',
#  ' NIBOR',
#  ' REITTAN GRAX',
#  ' LWAXANA (TELEPATHIC V.O.)',
#  ' LWAXANA',
#  ' FAREK',
#  ' TOG',
#  " FAREK (cont'd)",
#  " TOG (cont'd)",
#  ' TROI LWAXANA',
#  ' LWAXANA (O.S.)',
#  " LWAXANA (cont'd)",
#  " TOG'S COM VOICE",
#  ' TROI (TELEPATHIC V.O.)',
#  " LWAXANA (TELEPATHIC V.O., cont'd)",
#  " NIBOR (cont'd)",
#  " LWAXANA (TELEPATHIC V.O., cont'd) TROI",
#  ' TOG LWAXANA',
#  ' TOG FAREK (O.S.)',
#  ' GEORDI WESLEY',
#  ' FERENGI CREWMAN (V.O.)',
#  ' PICARD LWAXANA',
#  ' TEMPLE',
#  ' BEVERLY (V.O.)',
#  ' JOHN',
#  ' SUNAD',
#  " SUNAD (cont'd)",
#  " JOHN (cont'd)",
#  ' PICARD SUNAD',
#  " JOHN (cont'd) JOHN (Cont'd)",
#  ' HANSON',
#  ' SHELBY',
#  ' SHELBY (O.S.)',
#  ' HANSON (MONITOR)',
#  ' PICARD GUINAN',
#  " SHELBY'S COM VOICE",
#  ' GEORDI BEVERLY',
#  ' PICARD/BORG',
#  ' GEORDI SHELBY',
#  ' SHELBY RIKER',
#  ' RIKER (O.C.)',
#  " GUINAN GUINAN (Cont'd)",
#  ' LOCUTUS',
#  ' GLEASON',
#  ' LOCUTUS/PICARD',
#  ' PICARD & RIKER',
#  " TRANSPORTER OFFICER'S COM VOICE",
#  " BEVERLY'S (O.C.)",
#  ' BEVERLY (O.C.)',
#  ' JONO',
#  ' PICARD JONO',
#  " COMPUTER'S VOICE",
#  " JONO'S VOICE",
#  " MOIRA'S VOICE",
#  ' ENDAR',
#  ' PICARD ENDAR',
#  " CONNOR'S VOICE",
#  ' ENSIGN KOPF',
#  ' KOPF',
#  ' WORF (O.C.)',
#  ' WILLIE',
#  ' SOONG',
#  " SOONG SOONG (Cont'd)",
#  ' SOONG DATA',
#  ' LORE DATA',
#  " SOONG SOONG (Cont'd) SOONG (Cont'd)",
#  ' HELENA',
#  ' SERGEY',
#  ' RENE',
#  ' MARIE',
#  ' ROBERT',
#  ' LOUIS',
#  ' PICARD LOUIS',
#  ' GUINAN (O.C.)',
#  " JACK JACK (Cont'd) JACK (Cont'd)",
#  ' QUAICE',
#  " QUAICE QUAICE (Cont'd)",
#  ' CARA',
#  ' BEVERLY PICARD',
#  ' VOICE (WESLEY)',
#  ' TRAVELER (O.C.)',
#  ' WESLEY TRAVELER',
#  " TAN TSU'S VOICE",
#  " WORF WORF (Cont'd)",
#  ' MAN #1',
#  ' HAYNE',
#  ' ISHARA',
#  ' TAN TSU',
#  ' ISHARA (O.S)',
#  " ISHARA ISHARA (Cont'd)",
#  ' ALEXANDER',
#  " K'EHLEYR K'EHLEYR (Cont'd)",
#  ' GOWRON',
#  ' GUARD#2',
#  ' SECURITY OFFICER',
#  ' RIKER BEVERLY',
#  ' SONGI',
#  ' DIRGO',
#  ' DIRGO PICARD',
#  ' ALLENBY',
#  " CRUSHER'S COM VOICE",
#  ' DIRGO WESLEY',
#  ' BROOKS TROI',
#  ...]

# %% [markdown]
# Now we're cleaning the who column of any unneeded punctuation and whitespaces.

# %%
# remove the second name (or any word after the first)
StarTrek_df['who']=StarTrek_df['who'].str.replace(r"^(\s*(?:\S+\s+){1})\S+",r"\1")

# remove any unnecessary spaces
StarTrek_df['who'] = StarTrek_df['who'].str.strip()

# remove punctuations 
StarTrek_df['who']=StarTrek_df['who'].str.replace(r"[^-9A-Za-z ]", "")
# # remove punctuation and unnecessary characters 
# StarTrek_df['who'] = StarTrek_df['who'].str.replace(',', '')
# StarTrek_df['who'] = StarTrek_df['who'].str.replace('.', '')
# StarTrek_df['who'] = StarTrek_df['who'].str.replace('""', '')
# StarTrek_df['who'] = StarTrek_df['who'].str.replace('?', '')
# StarTrek_df['who'] = StarTrek_df['who'].str.replace('!', '')
# StarTrek_df['who'] = StarTrek_df['who'].str.replace(' ', '')
# StarTrek_df['who'] = StarTrek_df['who'].str.replace('"', '')

# Delete everything between the brackets
StarTrek_df['who'] = StarTrek_df['who'].str.replace(r"\(.*\)","")
# Out:
# <ipython-input-28-cac73b5da1eb>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   StarTrek_df['who']=StarTrek_df['who'].str.replace(r"^(\s*(?:\S+\s+){1})\S+",r"\1")
# <ipython-input-28-cac73b5da1eb>:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   StarTrek_df['who']=StarTrek_df['who'].str.replace(r"[^-9A-Za-z ]", "")
# <ipython-input-28-cac73b5da1eb>:18: FutureWarning: The default value of regex will change from True to False in a future version.
#   StarTrek_df['who'] = StarTrek_df['who'].str.replace(r"\(.*\)","")

# %%
# quick check if it's all single words
StarTrek_df['who'].sample(10)
# Out:
# 7432        WORF
# 39167     PICARD
# 67077       DATA
# 43383    BEVERLY
# 2381       RIKER
# 28257     SHELBY
# 4109     BEVERLY
# 51906     MADRED
# 9077       RIKER
# 6292      GEORDI
# Name: who, dtype: object

# %% [markdown]
# Now that the `who` column has been cleaned and organized properly, let's look at the meat of the dataset - our text. In order for our NLP analysis to go smoothly, we need to make sure the text is all lowercase (otherwise, we get unneeded repetitions), and remove punctuations as well.

# %%
# converting the text to lowercase 
StarTrek_df['text']= StarTrek_df['text'].str.lower()

# remove punctuation and unnecessary characters 
StarTrek_df['text']=StarTrek_df['text'].str.replace(r"[^-9A-Za-z ]", "")

# Delete everything between the brackets
StarTrek_df['text'] = StarTrek_df['text'].str.replace(r"\(.*\)","")
# Out:
# <ipython-input-40-f300f279bd79>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   StarTrek_df['text']=StarTrek_df['text'].str.replace(r"[^-9A-Za-z ]", "")
# <ipython-input-40-f300f279bd79>:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   StarTrek_df['text'] = StarTrek_df['text'].str.replace(r"\(.*\)","")

# %%
StarTrek_df.head()
# Out:
#                  episode  Episode  Season   Released     who  \
# 0  encounter at farpoint        1       1 1987-09-26  PICARD
# 1  encounter at farpoint        1       1 1987-09-26  PICARD
# 2  encounter at farpoint        1       1 1987-09-26  PICARD
# 3  encounter at farpoint        1       1 1987-09-26  PICARD
# 4  encounter at farpoint        1       1 1987-09-26  PICARD
#
#                                                 text  imdbRating
# 0   captains log stardate  our destination is pla...           7
# 1   my orders are to examine farpoint a starbase ...           7
# 2   acquainted with my new command this galaxy cl...           7
# 3   i am still somewhat in awe of its size and co...           7
# 4                several key positions most notably            7

# %% [markdown]
# Now that we have a cleaned dataset, now let's do some feature engineering and add more useful columns that could help us with our EDA.
#
# Next, we're adding a column that counts the number of words for each text line.

# %%
# counts the number of words within the text column and input the value
StarTrek_df['Word_Count'] = [len(x.split()) for x in StarTrek_df['text'].tolist()]

# %%
StarTrek_df.sample(10)
# Out:
#                             episode  Episode  Season   Released      who  \
# 1986   where no one has gone before        5       1 1987-10-24   PICARD
# 48572          time's arrow: part 2        1       6 1992-09-19   GEORDI
# 51970      chain of command: part 2       11       6 1992-12-19  JELLICO
# 49283             man of the people        3       6 1992-10-03    RIKER
# 33683                         clues       14       4 1991-02-09   PICARD
# 42298                  hero worship       11       5 1992-01-25   PICARD
# 61439                     parallels       11       7 1993-11-27    RIKER
# 60725               force of nature        9       7 1993-11-13   PICARD
# 23537                        déjà q       13       3 1990-02-03    RIKER
# 16985                       manhunt       19       2 1989-06-17   PICARD
#
#                                                     text  imdbRating  \
# 1986                           what's the boy doing here           8
# 48572           computer initialize the re-load circuits           8
# 51970      captain picard was not acting under my orders           9
# 49283   you wouldn't have recognized her her dress he...           6
# 33683   make it so and put out a hazard advisory to s...           8
# 42298   let's see if anyone's out there attempt a wid...           7
# 61439   captain picard sends his birthday wishes he w...           9
# 60725                    target their weapons array only           6
# 23537                             disengage tractor beam           8
# 16985   because because of his wonderful after-dinner...           6
#
#        Word_Count
# 1986            5
# 48572           5
# 51970           8
# 49283          13
# 33683          11
# 42298          13
# 61439          12
# 60725           5
# 23537           3
# 16985          17

# %% [markdown]
# Let's visualize this information a little bit. I want to know what were the most frequent words spoken by some of the main characters from the show. Namely:
#
# - PICARD
# - RIKER
# - DATA
# - TROI
# - WORF
# - BEVERLY
# - GEORDI
#
# and some recurring villians:
#
# - Q
# - LORE
#
# # TO DO (in the future)
#
# - make a loop where all the characters in a list in plotted out like below
#     - masking optional in the future

# %%
# create a list of characters (TEST)
characters = ['PICARD','WORF', 'BEVERLY', 'GEORDI', 'TROI',  'DATA', 'Q', 'RIKER', 'LORE']

# %%
# creating a dataframe that contains only one character (change the char, restart the kernel)
StarTrek_Char = StarTrek_df.loc[StarTrek_df['who'] == 'PICARD']

# %%
StarTrek_Char.sample(15)
# Out:
#                             episode  Episode  Season   Released     who  \
# 18622        the ensigns of command        2       3 1989-09-30  PICARD
# 45296                the first duty       19       5 1992-03-28  PICARD
# 1982   where no one has gone before        5       1 1987-10-24  PICARD
# 8694                      symbiosis       21       1 1988-04-16  PICARD
# 14492                  time squared       13       2 1989-04-01  PICARD
# 63200                   lower decks       15       7 1994-02-05  PICARD
# 29193                suddenly human        4       4 1990-10-13  PICARD
# 14545                  time squared       13       2 1989-04-01  PICARD
# 52345              ship in a bottle       12       6 1993-01-23  PICARD
# 33192                   devil's due       13       4 1991-02-02  PICARD
# 41591              a matter of time        9       5 1991-11-16  PICARD
# 35512                          qpid       20       4 1991-04-20  PICARD
# 15873                        q who?       16       2 1989-05-06  PICARD
# 63870                         masks       17       7 1994-02-19  PICARD
# 38872                     ensign ro        3       5 1991-10-05  PICARD
#
#                                                     text  imdbRating  \
# 18622                                                 oh           7
# 45296   i don't know that i've ever really told you h...           8
# 1982    with a physiology sufficiently different from...           8
# 8694                           no that's not what i want           7
# 14492   you're saying when our time intersects with t...           8
# 63200   if you're looking for a more lenient commande...           8
# 29193   i'm not convinced he was abused doctor i've t...           6
# 14545   using the gravitational pull of a star to "sl...           8
# 52345   professor i think there's something you shoul...           8
# 33192             you've identified her source of power            7
# 41591   well it's too bad you weren't a bit more inve...           7
# 35512   i look forward to giving tomorrow's keynote a...           7
# 15873   let's see if we can outrun it lietenant la fo...           9
# 63870                                       what's wrong           6
# 38872   but in forty years the bajorans have never at...           8
#
#        Word_Count
# 18622           1
# 45296          13
# 1982           16
# 8694            6
# 14492          26
# 63200          14
# 29193          29
# 14545          17
# 52345          11
# 33192           6
# 41591          36
# 35512          11
# 15873          22
# 63870           2
# 38872          12

# %%
# Start with one character:
text = " ".join(lines for lines in StarTrek_Char.text)

print ("There are {} words the character said.".format(len(text)))
# Out:
# There are 859140 words the character said.

# %%
# Create stopword list:
stopwords = set(STOPWORDS)

# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords, background_color="white", width=500, height=500, colormap='plasma').generate(text)

# Display the generated image:
# the matplotlib way:
plt.figure(figsize=(10,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# Now that we've visualized what these characters most used words are across the whole series, let's explore the dataset further.

# %%
# get the min and max (start and end dates) for the corpus of episodes
print(f"The series started on: {StarTrek_df['Released'].min()}")
print(f"The series ended on {StarTrek_df['Released'].max()}")
# Out:
# The series started on: 1987-09-26 00:00:00
# The series ended on 1995-08-23 00:00:00

# %%
print(f"The lowest score received is: {StarTrek_df['imdbRating'].min()}")
print(f"The highest score received is: {StarTrek_df['imdbRating'].max()}")
# Out:
# The lowest score received is: 3
# The highest score received is: 9

# %% [markdown]
# We'll be plotting a distribution of the ratings, as well as a time series of the entire series with the ratings plotted.

# %%
# looking at the distribution of the IMDB Ratings
values, counts = np.unique(StarTrek_df['imdbRating'], return_counts=True)
normalized_reviews = counts/counts.sum()

plt.figure()
plt.bar(values, normalized_reviews * 100, edgecolor='black', color='#002193')
plt.xlabel('imdbRating')
plt.ylabel('% of Reviews')
sns.despine()
plt.title("IMDB Ratings Distribution")
plt.show()

# %% [markdown]
# The distribution of the ratings on this dataset show a normally distributed plot. This is great to work with for modelling. Let's see how the ratings perform across time, as the show as been around for several seasons.

# %%
#plot the ratings count over the years
plt.figure(figsize = (30,5))
plt.plot(sorted(StarTrek_df['Released']), StarTrek_df['imdbRating'], color='#002193') # it's actually the number of reviews sum up for each year
plt.xlabel('Year')
plt.ylabel('IMDB Rating')
plt.title('Ratings Across the Years')
plt.show()

# %% [markdown]
# Now that we've made some handy visualizations, now we can move ahead to the nitty gritty of the NLP preprocessing workflow - tokenization!
