# %% [markdown]
# # Star Trek TNG - Master Clean Up
# ---
# ## INTRODUCTION
#
# - What is Star Trek? (a short history lesson)
#
# - Goal: Determine the best roster of characters using NLP and sentiment analysis to predict the highest rating on IMDB.
#     - Elaborate on applications in the real world.
#
# - Data Acquistition (link to GitHub)
#
# - Goal in this notebook is to clean the dataset, and preprocess it for modeling, along with some handy visualizations.

# %%
import pandas as pd 
import numpy as np 
import matplotlib as plt
import seaborn as sns
import dataframe_image as dfi

# %%
# read in the dataset
startrek_data = pd.read_csv(r'C:\Users\Katya\Documents\data\TNG.csv.gz', encoding= 'latin-1')

# %%
# taking a quick peek at the data
startrek_data.shape
# Out:
# (110176, 18)

# %%
startrek_data.head()
# Out:
#    Unnamed: 0                episode productionnumber setnames characters  \
# 0           1  encounter at farpoint              NaN      NaN        NaN
# 1           2  encounter at farpoint              NaN      NaN        NaN
# 2           3  encounter at farpoint              NaN      NaN        NaN
# 3           4  encounter at farpoint              NaN      NaN        NaN
# 4           5  encounter at farpoint              NaN      NaN        NaN
#
#       act scenenumber  scenedetails  partnumber         type           who  \
# 0  TEASER         1             NaN           1  description           NaN
# 1  TEASER         1             NaN           2       speech   PICARD V.O.
# 2  TEASER         2             NaN           3  description           NaN
# 3  TEASER         2             NaN           4       speech   PICARD V.O.
# 4  TEASER         3             NaN           5  description           NaN
#
#                                                 text  speechdescription  \
# 0   The U.S.S. Enterprise NCC 1701-D traveling at...              False
# 1   Captain's log, stardate 42353.7. Our destinat...              False
# 2         on the gigantic new Enterprise NCC 1701-D.              False
# 3   My orders are to examine Farpoint, a starbase...              False
# 4   Huge, with a giant wall diagram showing the i...              False
#
#      Released  Episode  imdbRating     imdbID  Season
# 0  1987-09-26      1.0         6.9  tt0094030     1.0
# 1  1987-09-26      1.0         6.9  tt0094030     1.0
# 2  1987-09-26      1.0         6.9  tt0094030     1.0
# 3  1987-09-26      1.0         6.9  tt0094030     1.0
# 4  1987-09-26      1.0         6.9  tt0094030     1.0

# %%
# filtered to only rows where a charactor spoke in the episode
startrekspeech = startrek_data.loc[startrek_data['type'] == 'speech']

# take a look
startrekspeech.head()
# Out:
#    Unnamed: 0                episode productionnumber setnames characters  \
# 1           2  encounter at farpoint              NaN      NaN        NaN
# 3           4  encounter at farpoint              NaN      NaN        NaN
# 5           6  encounter at farpoint              NaN      NaN        NaN
# 7           8  encounter at farpoint              NaN      NaN        NaN
# 9          10  encounter at farpoint              NaN      NaN        NaN
#
#       act scenenumber  scenedetails  partnumber    type           who  \
# 1  TEASER         1             NaN           2  speech   PICARD V.O.
# 3  TEASER         2             NaN           4  speech   PICARD V.O.
# 5  TEASER         3             NaN           6  speech   PICARD V.O.
# 7  TEASER         4             NaN           8  speech   PICARD V.O.
# 9  TEASER         5             NaN          10  speech   PICARD V.O.
#
#                                                 text  speechdescription  \
# 1   Captain's log, stardate 42353.7. Our destinat...              False
# 3   My orders are to examine Farpoint, a starbase...              False
# 5   acquainted with my new command, this Galaxy C...               True
# 7   I am still somewhat in awe of its size and co...              False
# 9            several key positions, most notably ...               True
#
#      Released  Episode  imdbRating     imdbID  Season
# 1  1987-09-26      1.0         6.9  tt0094030     1.0
# 3  1987-09-26      1.0         6.9  tt0094030     1.0
# 5  1987-09-26      1.0         6.9  tt0094030     1.0
# 7  1987-09-26      1.0         6.9  tt0094030     1.0
# 9  1987-09-26      1.0         6.9  tt0094030     1.0

# %%
StarTrek_Cols = startrekspeech.filter(['episode', 'type', 'who', 'Episode', 'imdbRating', 'Season', 'text'], axis=1)

# %%
# remove leading whitespaces
StarTrek_Cols['who'] = StarTrek_Cols['who'].str.lstrip()

# %%
# remove (V.O.) 
StarTrek_Cols['who'] = StarTrek_Cols['who'].str.replace(r'PICARD\s\S*', '', regex=True)

# %%
# StarTrek_Cols['who']= StarTrek_Cols['who'].apply(lambda x: x.split('PICARD')[0])

# %%
# # remove whitespaces
# StarTrek_Cols['who'] = StarTrek_Cols['who'].str.replace(' ', '')

# %%
# checking the if regex worked
StarTrek_Cols['who'].unique().tolist()
# Out:
# ['',
#  'PICARD',
#  'DATA',
#  'TROI',
#  'WORF',
#  'CONN',
#  '"Q" (ELIZABETHAN)',
#  'MEDIC',
#  '"Q" (MARINE CAPTAIN)',
#  ' (MARINE CAPTAIN)  (MARINE CAPTAIN)',
#  '"Q" (21ST CENTURY)',
#  'TASHA',
#  "PICARD'S INTERCOM VOICE",
#  'MANDARIN-BAILIFF',
#  'FUTURE MILITARY OFFICER',
#  'MILITARY OFFICER',
#  '"Q" (JUDGE)',
#  '"Q" (JUDGE) MANDARIN-BAILIFF',
#  'DATA "Q" (JUDGE)',
#  'OPS',
#  "RIKER'S VOICE",
#  'ZORN',
#  'RIKER',
#  "ZORN ZORN (Cont'd)",
#  'WESLEY',
#  'BEVERLY',
#  'MARKHAM',
#  'GEORDI/MARKHAM',
#  'GEORDI',
#  'BANDI WOMAN',
#  "DATA'S VOICE",
#  'RIKER (V.O.)',
#  'ADMIRAL',
#  "PICARD'S VOICE",
#  "TROI'S VOICE",
#  'YOUNG ENSIGN',
#  'COMPUTER VOICE',
#  'RIKER COMPUTER VOICE',
#  'RIKER DATA',
#  "WESLEY'S VOICE",
#  'BEVERLY WESLEY',
#  "TASHA'S VOICE",
#  'WES',
#  'SECURITY VOICE',
#  "ZORN'S VOICE",
#  'SECURITY POSITION',
#  'OPERATIONS POSITION',
#  "ZORN'S VOICE PICARD",
#  'INTERCOM VOICE',
#  '"Q" (STARFLEET)',
#  "WOMAN'S COM VOICE",
#  'TRANSPORTER CHIEF',
#  "TASHA'S COM VOICE",
#  "RIKER'S COM VOICE",
#  "BEVERLY'S COM VOICE",
#  ' O.)',
#  "TROI'S COM VOICE",
#  'WESLEY (V.O)',
#  "PICARD'S COM VOICE",
#  'DATA (V.O.)',
#  'SHIMODA',
#  'MACDOUGAL',
#  "WESLEY'S COM VOICE",
#  'SECURITY COM VOICE',
#  " (Cont'd)",
#  'CREWMAN',
#  "WORF'S COM VOICE",
#  "MACDOUGAL'S COM VOICE",
#  'LUTAN',
#  'HAGON',
#  'DATA PICARD',
#  'DATA (O.S.)',
#  'BEVERLY (O.S.)',
#  'YAREENA (O.S.)',
#  'TASHA YAREENA',
#  'YAREENA',
#  "DATA DATA (Cont'd)",
#  'DATA GEORDI',
#  "TRANSPORTER CHIEF'S COM VOICE",
#  'DATA ',
#  'TRANSPORTER CHIEF (V.O.)',
#  'GEORDI (V.O.)',
#  'FACE',
#  'TROI RIKER',
#  'STEVEN',
#  'VICTORIA',
#  'TROI VICTORIA',
#  'WYATT',
#  'MRS. TROI',
#  'MRS. TROI TELEPATHIC V.O.',
#  'TROI TELEPATHIC V.O.',
#  'VALEDA',
#  ' RIKER',
#  'RIKER PICARD',
#  'WYATT (V.O.)',
#  "PICARD'S (V.O.)",
#  'WRENN',
#  'ARIANA',
#  'HOMN',
#  'MRS. TROI TELEPATHIC V. O.',
#  'KOSINSKI',
#  'ARGYLE',
#  'ASSISTANT',
#  "GEORDI'S COM VOICE",
#  'KOSINSKI PICARD',
#  'FIRST CREWMEMBER',
#  'MOTHER PICARD',
#  'TRAVELER',
#  'TRAVELER PICARD',
#  'CREWMEMBER',
#  "TROI RIKER'S COM VOICE",
#  'WORF (V.O.)',
#  "TAAR'S COM VOICE",
#  'TAAR (V.O.)',
#  'TAAR',
#  'RIKER (V.O) DATA (V.O.)',
#  'RIKER/DATA (V.O)',
#  'TROI PICARD',
#  'LETEK',
#  'MORDOC',
#  'LETEK RIKER (V.O.)',
#  'RIKER LETEK',
#  'TASHA (V. O.)',
#  'KYRON',
#  'PORTAL FIGURE',
#  'PORTAL',
#  'RIKER GEORDI',
#  'KAYRON',
#  'TASHA RIKER',
#  'PORTAL RIKER',
#  'SSESTAR',
#  'TASHA DATA',
#  'GEORDI PICARD',
#  "BADAR N'D'D",
#  "SINGH'S COM VOICE",
#  'SINGH',
#  'RIKER AND TASHA',
#  'DATA TASHA',
#  'FIRST SECURITY GUARD',
#  'RIKER)',
#  'PICARD)',
#  'RIKER (O.S.)',
#  'TROI (O.S.)',
#  'WESLEY)',
#  'RIVAN',
#  'LIATOR',
#  'RIVAN WORF',
#  'FIRST EDO CITIZEN',
#  'FIRST EDO BOY',
#  'EDO GIRL',
#  'GEORDI TASHA',
#  'DATA CONN CREWMEMBER',
#  'CONN CREWMEMBER PICARD',
#  'CONN CREWMEMBER',
#  'EDOLORD (V.O.)',
#  'WESLEY EDO GIRL',
#  'RIVAN TASHA',
#  'SECOND EDO BOY',
#  'FIRST MEDIATOR',
#  'SECOND MEDIATOR',
#  'WESLEY MEDIATOR',
#  "TASHA'S COM VOICE GEORDI",
#  ' ',
#  'EDOLORD (V. O.)',
#  'MEDICAL TECHNICIAN',
#  'DATA BEVERLY',
#  'RIVAN (O.S.)',
#  'WESLEY (O.S.)',
#  'BOK',
#  'KAZAGO',
#  'RATA',
#  'VOICES (V.O.)',
#  "PICARD'S RECORDED VOICE",
#  'VOICES (V. O.)',
#  "WESLEY WESLEY (Cont'd)",
#  'RIKER TROI',
#  'COMPUTER',
#  'BOK (O.S.)',
#  'RIKER (V.O.) TASHA',
#  'FIRST VOICE (V.O.)',
#  'SECOND VOICE (V.O.)',
#  'THIRD VOICE (V.O.)',
#  '"Q" (V.O.)',
#  '"Q" (ADMIRAL)',
#  'GEORDI DATA',
#  '"Q" (MARSHAL)',
#  'RIKER "Q" (MARSHAL)',
#  'TASHA (O.S.)',
#  '"Q" (MARSHAL) (O.S.)',
#  '"Q" (MARSHAL) "Q" (Cont\'d)',
#  '"Q" (MARSHAL) PICARD',
#  '"Q". (MARSHAL)',
#  '"Q" (DATA)',
#  "ENGINEER'S COM VOICE",
#  '"Q" (O.S.)',
#  '"Q" (COMMANDER)',
#  'RIKER "Q" (COMMANDER)',
#  '"Q" (COMMANDER) "Q" (Cont\'d)',
#  "DATA'S COM VOICE",
#  'WOMAN',
#  '"Q" (BROTHER) (O.S.)',
#  '"Q" (BROTHER)',
#  'DATA RIKER',
#  'WESLEY RIKER',
#  'JAMESON',
#  'KARNAS',
#  'KARNAS (V.O.)',
#  'JAMESON (V.O.)',
#  'ANNE JAMESON',
#  'ANNE',
#  'ANNE (V.O.)',
#  'JAMESON (O.S.)',
#  'ANNE TROI',
#  'JAMESON PICARD',
#  'JAMESON (BOY)',
#  ' VOICE',
#  'SECRETARY',
#  'JESSICA',
#  'LEECH',
#  'WHALEN',
#  'VENDOR',
#  'VENDOR PICARD',
#  'BELL (O.S.)',
#  'BELL',
#  'MCNARY',
#  "JARADAN'S COM VOICE",
#  "JARADAN'S COM VOICE RIKER",
#  "JARALAN'S COM VOICE",
#  'BELL PICARD',
#  'McNARY',
#  'SERGEANT',
#  'SERGANT',
#  'REDBLOCK',
#  'THUG',
#  "GEORDI RIKER'S COM VOICE",
#  'REDBLOCK DATA',
#  'DATA (O. S.)',
#  'ARGYLE (O.S.)',
#  'LORE',
#  'LORE WESLEY',
#  "LORE LORE (Cont'd)",
#  'WORF DATA',
#  'WESLEY PICARD',
#  'LORE (O.S.) LORE',
#  'LORE (O.S.)',
#  "FEMALE'S COM VOICE",
#  "BEATA'S COM VOICE",
#  'BEATA',
#  'TRENT',
#  'ARIEL',
#  'RAMSEY',
#  "ENGINEERING'S COM VOICE",
#  "RAMSEY RAMSEY (Cont'd)",
#  'QUINTEROS',
#  'BYNAR ONE ZERO',
#  'BYNAR ZERO ONE PICARD',
#  'ZERO ONE',
#  'ONE ZERO PICARD',
#  'ONE ZERO ZERO ONE ONE ZERO',
#  'ZERO ONE ONE ZERO QUINTEROS',
#  'ONE ZERO',
#  'GEORDI (O.S.)',
#  'ZERO ZERO',
#  'ONE ONE ZERO ZERO ONE ONE ZERO ZERO ONE ONE RIKER',
#  'ONE ONE',
#  'ZERO ZERO (SUBTITLED)',
#  'ONE ONE (SUBTITLED)',
#  'ONE ONE RIKER',
#  'MINUET',
#  'ONE ZERO WESLEY',
#  'ONE ZERO ZERO ONE',
#  'ONE ZERO ZERO ONE ONE ZERO WESLEY',
#  'ZERO ONE WESLEY',
#  'BASS',
#  'DRUMMER',
#  'PIANIST',
#  'STARBASE COMPUTER (V.O.)',
#  'AD LIBBED VOICES',
#  'STARBASE COM VOICE',
#  'QUINTEROS (O.S.)',
#  'MINUET RIKER',
#  'QUINTEROS DATA',
#  'COMPUTER (V.O.)',
#  'ZERO ONE ONE ZERO ZERO ONE',
#  'ONE ZERO ZERO ZERO ONE ONE ZERO ZERO ONE ONE PICARD',
#  'ONE ZERO RIKER',
#  'ONE ONE PICARD',
#  'MANDL',
#  'LUISA',
#  'BENSON',
#  'BENSEN',
#  'MALENCON',
#  "BENSEN'S COM VOICE",
#  'BEVERLY COMPUTER VOICE',
#  "BENSEN RIKER'S COM VOICE",
#  'FEMALE COM VOICE',
#  'ENGINEER',
#  'TRANSLATOR VOICE',
#  "TRANSPORTER CHIEF'S COM VOICE RIKER",
#  'HARRY',
#  'DR. BERNARD',
#  'RASHELLA',
#  'RADUE',
#  "RADUE'S COM VOICE",
#  'KATIE',
#  'DUANA',
#  'ALEXANDRA',
#  'TOYA',
#  'LEDA',
#  'ACCOLAN',
#  'MELIAN',
#  'DUANE',
#  'CUSTODIAN VOICE',
#  'WESLEY DUANA',
#  'DUANA WESLEY DUANA',
#  'HARRY PICARD',
#  ' COM VOICE',
#  'QUINN',
#  'REMMICK',
#  'OLIANA',
#  "T'SHANIK",
#  'MORDOCK',
#  'CHANG',
#  'TASHA PICARD',
#  'JAKE',
#  'JAKE (V.O.)',
#  'RONDON',
#  "REMMICK'S COM VOICE",
#  'TECHNICIAN #1 (V.O.)',
#  'COMPUTER VOICE (V.O.)',
#  'TECHNICIAN #1',
#  'TECHNICIAN #2',
#  'CHANG.',
#  'KORRIS',
#  'KONMEL',
#  'NURSE',
#  'KONMEL KORRIS',
#  "K'NERA",
#  'GUARD',
#  "THE PEDDLER'S COM VOICE",
#  'SOLIS',
#  'RICE (O.S.)',
#  'RICE',
#  'GEORDI (V. O.)',
#  'LOGAN',
#  'LIAN',
#  "LOGAN'S COM VOICE",
#  'THE PEDDLER',
#  'PEDDLER',
#  "BEN'S COM VOICE PICARD",
#  "BEN'S COM VOICE",
#  'LYNCH',
#  "LYNCH'S COM VOICE",
#  "TROI'S COM VOICE BEN'S COM VOICE",
#  'ARMUS',
#  'RIKER ARMUS',
#  'ARMUS (O.S.)',
#  'ARMUS (O.S.) TROI',
#  'TROI BEVERLY',
#  "TASHA TASHA (Cont'd)",
#  'VOICE (V.O.)',
#  "T'JON (V.O.)",
#  'SOBI (V.O.)',
#  'LANGOR (V.O.)',
#  "T'JON'S COM VOICE",
#  "TASHA T'JON'S COM VOICE",
#  'RIKER TASHA',
#  "T'JON",
#  'ROMAS',
#  'SOBI',
#  'LANGOR',
#  "SOBI T'JON",
#  "ROMAS T'JON",
#  "T'Jon",
#  'MARGAN',
#  "MANHEIM'S COM VOICE",
#  'EDOUARD',
#  'FRANCINE',
#  'GABRIELLE',
#  'LAURA (V.O.)',
#  'LAURA',
#  'MANHEIM',
#  'WORF PICARD',
#  'PAUL',
#  "MANHEIM'S",
#  'LAURA (O.S.)',
#  "LAURA (Cont'd)",
#  'KEEL',
#  'KEEL (O.S.)',
#  'BOLIAN',
#  'RIXX',
#  'TRYLA',
#  'SAVAR',
#  'AARON',
#  'QUINN (O.S.)',
#  ' PICARD',
#  'BEVERLY GEORDI',
#  'DATA WORF',
#  'RALPH',
#  'SONNY',
#  'CLARE',
#  "RALPH'S COM VOICE",
#  'RALPH PICARD',
#  'TEBOK',
#  'THEI',
#  'REPULSE VOICE',
#  'SICKBAY VOICE',
#  'GUINAN',
#  'PULASKI',
#  "PULASKI PULASKI (Cont'd) RIKER",
#  'HESTER',
#  "PULASKI PICARD'S COM VOICE",
#  'PULASKI TROI',
#  'IAN',
#  "PULASKI'S COM VOICE",
#  'PULASKI DATA',
#  'MISS GLADSTONE',
#  'PICARD.',
#  "GEORDI PICARD'S COM VOICE",
#  'HESTER RIKER',
#  'WORF RIKER',
#  'WORF (O.S.)',
#  'HASKELL',
#  'NAGILUM',
#  ' TROI',
#  'PULASKI WORF RIKER',
#  'COMPUTER VOICE)',
#  'DATA COMPUTER VOICE',
#  'ASSISTANT ENGINEER',
#  'LESTRADE (O.S.)',
#  'LESTRADE',
#  'PULASKI (O.S.)',
#  'PULASKI GEORDI',
#  'PIE MAN',
#  'WHORE',
#  'PROSTITUTE (WHORE)',
#  'PROSTITUTE',
#  'MORIARTY',
#  'DATA)',
#  "MORIARTY MORIARTY (Cont'd)",
#  'GEORDI RIKER',
#  'MORIARTY PULASKI',
#  'RUFFIAN',
#  'MORIARTY PICARD',
#  "OKONA'S COM VOICE",
#  'OKONA',
#  "B.G. ROBINSON'S COM VOICE",
#  'B.G. ROBINSON',
#  'THE COMIC',
#  'THE COMIC DATA',
#  'DEBIN',
#  'KUSHELL',
#  "OKONA OKONA (Cont'd)",
#  'BENZAN',
#  'HUSHELL',
#  'YANAR',
#  'PULASKI (V.O.)',
#  'KAREEN',
#  "MAN'S COM VOICE",
#  'GUINAN DATA',
#  'PULASKI RIKER',
#  'GRAVES (O.S.)',
#  'GRAVES',
#  'GRAVES KAREEN',
#  'GRAVES DATA',
#  'KAREEN PICARD',
#  'KAREEN (O.S.)',
#  'KAREEN)',
#  'WARRIOR/ADONIS',
#  'SCHOLAR/ARTIST',
#  'CHORUS',
#  'SCHCLAR/ARTIST',
#  'WOMAN GEORDI',
#  'TROI WARRIOR/ADONIS',
#  'RIVA',
#  "FIRST LEADER'S COM VOICE",
#  "SECOND LEADER'S COM VOICE",
#  'SCHOLAR/ARTIST RIKER',
#  'RIKER WARRIOR/ADONIS RIKER',
#  'FIRST LEADER',
#  "CHIEF O'BRIEN",
#  'MENDON',
#  'WESLEY MENDON',
#  'KARGAN',
#  'MENDON PICARD',
#  'TACTICS OFFICER',
#  'KLAG',
#  'VEKMA',
#  "CAPTAIN KARGAN'S COM VOICE",
#  "O'BRIEN",
#  'PHILLIPA',
#  'NAKAMURA',
#  'MADDOX',
#  'PICARD/RIKER',
#  'MADDOX PHILLIPA',
#  'GIBSON',
#  'ANYA',
#  'SALIA',
#  'WESLEY GEORDI',
#  "SALIA'S COM VOICE",
#  'TEENAGE GIRL',
#  'RIKER GUINAN',
#  'ARON',
#  "ANYA'S COM VOICE",
#  'SALIA WESLEY',
#  'ANYA (O.S.)',
#  'GIBSON PICARD',
#  'WESLEY SALIA (O.S.)',
#  'VOICE',
#  'VARLEY',
#  'TARIS',
#  'DOCTOR',
#  "O'BRIEN PICARD",
#  "O'BRIEN'S COM VOICE",
#  'WILLIAMS',
#  'BELLBOY',
#  'ASSISTANT MANAGER',
#  'TEXAS',
#  'VANESSA',
#  'DEALER',
#  "RIKER'S COM VOICE PICARD",
#  "RIKER RIKER (Cont'd)",
#  'MIKEY D',
#  'CROUPIER (O.S.)',
#  'CROUPIER',
#  'TEXAS (O.S.)',
#  'ASSISTANT MANAGER (O.S.)',
#  "RIKER PICARD'S COM VOICE",
#  'TROI PULASKI',
#  'P2',
#  'RIKER PULASKI',
#  "HERBERT'S COM VOICE",
#  'HERBERT',
#  'KYLE',
#  'KYLE PULASKI',
#  'TROI WORF',
#  "KYLE KYLE (Cont'd)",
#  'RIKER WESLEY',
#  'DAVIES',
#  'SARJENKA (V.O.)',
#  'PULASKI PULASKI',
#  'HILDEBRANT',
#  'ALANS',
#  'ALANS HILDEBRANT',
#  'SARJENKA',
#  'SONYA',
#  'SONYA PICARD',
#  'SONYA GEORDI',
#  'Q',
#  'SONYA (O.S.)',
#  'GEORDI (O.S).',
#  'Q PICARD',
#  'Q ',
#  'RIKER Q',
#  'Q Q',
#  'WESLEY COM VOICE',
#  'DATA COM VOICE',
#  'WORF COM VOICE',
#  'BORG',
#  'Q (O.S.)',
#  'GEORGI',
#  'GEORDI COM VOICE',
#  'Q WORF',
#  'GREBNEDLOG',
#  'REGINOD',
#  'SURGEON',
#  "GEORDI GEORDI (Cont'd)",
#  'BIOMOLECULAR PHYSIOLOGIST',
#  'COMPUTER (V.O) RIKER',
#  'REGINOD GEBNEDLOG',
#  'COMPUTER VOICE RIKER',
#  'DANILO',
#  'BRENNA',
#  'DANILO BRENNA (V.O.)',
#  'OLD MAN',
#  'BRENNA (V.O.) DANILO',
#  'GRANGER',
#  'GRANGER 1B',
#  "DANILO DANILO (Cont'd)",
#  'BRENNA PICARD',
#  "BRENNA BRENNA (Cont'd)",
#  'TRANSPORT PILOT',
#  'TRANSPORT PILOT MRS. TROI (V.O.)',
#  'MRS. TROI (V.O.)',
#  "MRS. TROI MRS. TROI (Cont'd)",
#  'MRS TROI TROI',
#  " TROI (Cont'd)",
#  'SECRETARY (V.O.)',
#  'SLADE',
#  'TOUGHGUY',
#  'REX',
#  'PULASKI COM VOICE',
#  'MRS. TROI (O.S.)',
#  'SLADE REX',
#  'ANTEDIANS',
#  'ANTEDIAN FEMALE',
#  "PULASKI (cont'd)",
#  'CLANCEY',
#  'ADMIRAL GROMEK',
#  "ADMIRAL GROMEK (cont'd)",
#  "K'EHLEYR",
#  "RIKER (cont'd)",
#  "K'EHLEYR (cont'd)",
#  "WORF (cont'd)",
#  "K'EHLEYR TROI",
#  "K'EHLEYR WORF",
#  "K'EHLYR",
#  "K'EHLEYR (O.S., cont'd)",
#  'TACTICAL CREWMAN',
#  "K'TEMOC",
#  "K'TEMOC (cont'd)",
#  'KOLRAMI',
#  'RIKER KOLRAMI',
#  'BURKE',
#  'KOLRAMI PICARD',
#  'DATA KOLRAMI',
#  'NAGEL',
#  'GEORDI WESLEY RIKER',
#  'TROI DATA',
#  'BRACTOR',
#  'TACTICIAN',
#  'TROI/PULASKI',
#  "O'BRIEN (cont'd)",
#  "GEORDI (cont'd)",
#  "PULASKI (V.O., cont'd)",
#  'EDO MARBLE PLAYER',
#  'EDO SPECTATOR',
#  'BEATA RIKER',
#  "KARGAN KARGAN (cont'd)",
#  'SHELIAK VOICE',
#  'HARITATH',
#  'KENTOR',
#  'GOSHEVEN',
#  "DATA DATA (cont'd)",
#  "ARD'RIAN (O.S.)",
#  "ARD'RIAN",
#  'SHELIAK',
#  "ARD'RIAN DATA",
#  "ARD'RIAN (cont'd)",
#  "DATA (cont'd)",
#  "GOSHEVEN GOSHEVEN (Cont'd)",
#  "GOSHEVEN (cont'd)",
#  "HARITATH (cont'd)",
#  'GOSHEVEN (O.S.)',
#  'STUBBS',
#  'CREWMEMBER #1',
#  "CREWMEMBER#1'S COM VOICE",
#  'ERIC',
#  'ANNETTE',
#  'DATA/NANITE',
#  'KEVIN',
#  'RISHON',
#  "TROI TROI (Cont'd)",
#  "RISHON RISHON (Cont'd)",
#  'RISON',
#  "KEVIN KEVIN (Cont'd)",
#  'BARRON',
#  'LIKO',
#  'OJI',
#  'BARRON (O.S.)',
#  'LIKO (O.S.)',
#  'BEVERLY RIKER',
#  "TROI (cont'd)",
#  'OJI (O.S.)',
#  'OJI FENTO',
#  'FENTO',
#  'NURIA',
#  'HALI (O.S.)',
#  'HALI',
#  "LIKO'S COM VOICE",
#  "DATA'S COM VOICE DATA'S COM VOICE (cont'd)",
#  "LIKO (cont'd)",
#  "NURIA (cont'd)",
#  "BEVERLY (cont'd)",
#  'TEACHER',
#  'JEREMY',
#  'JEREMY TROI',
#  'WESLEY BEVERLY',
#  'MARLA',
#  'CHRISTY',
#  'CHRISTY (O.S.)',
#  "GALEK SAR GALEK SAR (Cont'd)",
#  "LEAH'S VOICE",
#  'LEAH',
#  'GEORDI COMPUTER VOICE',
#  'GALEK SAR (MONITOR)',
#  'GEORDI LEAH',
#  'PATAHK',
#  'TOMALAK',
#  'BOCHRA',
#  'BEVELRY',
#  "TROI TROI (Cont'd) COMPUTER",
#  'BHAVANI',
#  'MENDOZA',
#  'LEYOR',
#  'DEVINONI',
#  'GOSS',
#  'ARRIDOR',
#  "ARRIDOR ARRIDOR (Cont'd)",
#  'DEVINONI (O.S.)',
#  'BEVERLY & TROI',
#  'DEVINONI LEYOR',
#  'TROI DEVINONI',
#  "DEVINONI DEVINONI (Cont'd)",
#  'MAROUK',
#  'MAROUK (O.S.)',
#  'YUTA',
#  "YUTA (cont'd)",
#  'BRULL',
#  'YUTA (O.S.)',
#  'VOLNOTH',
#  "VOLNOTH (cont'd)",
#  'TEMAREK (O.S.)',
#  'TEMAREK',
#  "BRULL (cont'd)",
#  'YUTA RIKER',
#  'CHORGAN',
#  'CHORGAN (O.S.)',
#  'CHORGAN MAROUK',
#  'BATES',
#  'DATA (KING HENRY)',
#  "SETAL'S COM VOICE",
#  'SETAL',
#  'DATA (O.C.)',
#  'ADMIRAL HADEN',
#  "ADMIRAL HADEN ADMIRAL HADEN (Cont'd)",
#  'JAROK',
#  'JAROK ',
#  'NAYROK',
#  'ZAYNAR',
#  'RIKER WORF',
#  "O'BRIEN'S VOICE",
#  'SECURITY MAN',
#  'ROGA',
#  "NAYROK NAYROK (Cont'd)",
#  'WAGNOR',
#  'SECURITY GUARD COM VOICE',
#  'TROI NAYROK',
#  'NAYROCK',
#  'POLICEMAN',
#  'WAITER',
#  "ENGINEER'S VOICE",
#  'FINN',
#  "FINN FINN (Cont'd)",
#  'ALEXANA',
#  "ALEXANA (cont'd)",
#  'FINN BEVERLY',
#  'KATIK',
#  "FINN'S VOICE",
#  'GARIN',
#  'SCIENTIST',
#  'Q TROI',
#  "Q Q (Cont'd)",
#  'Q GEORDI',
#  'Q2',
#  'Q2 (V.O.)',
#  'KRAG',
#  'APGAR',
#  'MANUA (O.S.)',
#  'MANUA',
#  'TAYNA',
#  "KRAG (cont'd)",
#  "APGAR (cont'd)",
#  "MANUA (cont'd)",
#  'APGAR (O.S.)',
#  'KRAG (O.S.)',
#  'WORF GUINAN',
#  "GARRETT'S COM VOICE",
#  'GARRETT',
#  "BEVERLY BEVERLY (Cont'd)",
#  'GARRETT RIKER',
#  'CASTILLO',
#  'TASHA (com)',
#  'COM VOICE',
#  'KLINGON COM VOICE',
#  "GUINAN'S COM VOICE",
#  'LAL',
#  'ADMIRAL HAFTEL',
#  'BALLARD',
#  'GUINAN (O.S.)',
#  "HAFTEL ADMIRAL HAFTEL (Cont'd)",
#  'LAL (O.S.)',
#  'TECHNICIAN',
#  'KURN',
#  'GEORDI KURN',
#  'KURN WORF',
#  "K'MPEC",
#  'DURAS',
#  "DURAS DURAS (Cont'd)",
#  'KAHLEST',
#  'FALSE PICARD',
#  'HARO',
#  "HARO (cont'd)",
#  'THOLL (O.S.)',
#  'THOLL',
#  "WESLEY (cont'd)",
#  'FALSE ',
#  'ESOQQ',
#  "DATA (Cont'd)",
#  "ESOQQ (cont'd)",
#  'ESOQQ THOLL',
#  'THOLL PICARD',
#  'BEVERLY FALSE PICARD',
#  'GEORDI TROI',
#  'ALIEN #1',
#  'ALIEN #2',
#  'ALIEN #4',
#  ' #4',
#  'AJUR',
#  'BORATUS',
#  'PIKER',
#  ' RIKER ',
#  'VASH',
#  'JOVAL (V.O.)',
#  'JOVAL',
#  'SOVAK',
#  'VASH (V.O.)',
#  'VASH ',
#  'SOVAK (O.S.)',
#  'RIKER (COM VOICE)',
#  "VASH VASH (Cont'd)",
#  'DESOTO',
#  'TAM',
#  "TAM TAM (Cont'd)",
#  'TROI ',
#  'TAM TROI',
#  'TAM TROI TAM TROI',
#  'ROMULAN COMMANDER',
#  "TAM'S COM VOICE",
#  "TAM (cont'd)",
#  'HOLO-GUINAN',
#  'BARCLAY',
#  'HOLO-GEORDI',
#  'HOLO-RIKER',
#  'HOLO-TROI',
#  'DUFFY',
#  'GEORDI BARCLAY',
#  'HOLO-BEVERLY',
#  'HOLO-WESLEY',
#  'HOLO-DATA',
#  'HOLO-PICARD',
#  "BARCLAY BARCLAY (Cont'd)",
#  'GEORDI GEORDI',
#  'VARRIA',
#  'FAJO',
#  "FAJO (cont'd)",
#  "DATA'S VOICE (V.O.)",
#  "DATA'S VOICE (RECORDED)",
#  'TOFF (O.S.)',
#  'FAJO (O.S.)',
#  'TOFF',
#  'VARRIA TOFF',
#  "FAJO'S COM VOICE",
#  'FAJO DATA',
#  'MENDROSSEN',
#  'SAKKATH',
#  'SAREK',
#  'PERRIN',
#  'SAKKATH DATA',
#  'SCIENCE CREWMAN',
#  "SAREK SAREK (Cont'd)",
#  'SAREK PICARD',
#  'SAREK (V.O.)',
#  'NIBOR',
#  'REITTAN GRAX',
#  'LWAXANA (TELEPATHIC V.O.)',
#  'LWAXANA',
#  'FAREK',
#  'TOG',
#  "FAREK (cont'd)",
#  "TOG (cont'd)",
#  'TROI LWAXANA',
#  'LWAXANA (O.S.)',
#  "LWAXANA (cont'd)",
#  "TOG'S COM VOICE",
#  'TROI (TELEPATHIC V.O.)',
#  "LWAXANA (TELEPATHIC V.O., cont'd)",
#  "NIBOR (cont'd)",
#  "LWAXANA (TELEPATHIC V.O., cont'd) TROI",
#  'TOG LWAXANA',
#  'TOG FAREK (O.S.)',
#  'GEORDI WESLEY',
#  'FERENGI CREWMAN (V.O.)',
#  'TEMPLE',
#  'BEVERLY (V.O.)',
#  'JOHN',
#  'SUNAD',
#  "SUNAD (cont'd)",
#  "JOHN (cont'd)",
#  "JOHN (cont'd) JOHN (Cont'd)",
#  'HANSON',
#  'SHELBY',
#  'SHELBY (O.S.)',
#  'HANSON (MONITOR)',
#  "SHELBY'S COM VOICE",
#  'GEORDI BEVERLY',
#  'PICARD/BORG',
#  'GEORDI SHELBY',
#  'SHELBY RIKER',
#  'RIKER (O.C.)',
#  "GUINAN GUINAN (Cont'd)",
#  'LOCUTUS',
#  'GLEASON',
#  'LOCUTUS/PICARD',
#  "TRANSPORTER OFFICER'S COM VOICE",
#  "BEVERLY'S (O.C.)",
#  'BEVERLY (O.C.)',
#  'JONO',
#  "COMPUTER'S VOICE",
#  "JONO'S VOICE",
#  "MOIRA'S VOICE",
#  'ENDAR',
#  "CONNOR'S VOICE",
#  'ENSIGN KOPF',
#  'KOPF',
#  'WORF (O.C.)',
#  'WILLIE',
#  'SOONG',
#  "SOONG SOONG (Cont'd)",
#  'SOONG DATA',
#  'LORE DATA',
#  "SOONG SOONG (Cont'd) SOONG (Cont'd)",
#  'HELENA',
#  'SERGEY',
#  'RENE',
#  'MARIE',
#  'ROBERT',
#  'LOUIS',
#  'GUINAN (O.C.)',
#  "JACK JACK (Cont'd) JACK (Cont'd)",
#  'QUAICE',
#  "QUAICE QUAICE (Cont'd)",
#  'CARA',
#  'BEVERLY PICARD',
#  'VOICE (WESLEY)',
#  'TRAVELER (O.C.)',
#  'WESLEY TRAVELER',
#  "TAN TSU'S VOICE",
#  "WORF WORF (Cont'd)",
#  'MAN #1',
#  'HAYNE',
#  'ISHARA',
#  'TAN TSU',
#  'ISHARA (O.S)',
#  "ISHARA ISHARA (Cont'd)",
#  'ALEXANDER',
#  "K'EHLEYR K'EHLEYR (Cont'd)",
#  'GOWRON',
#  'GUARD#2',
#  'SECURITY OFFICER',
#  'RIKER BEVERLY',
#  'SONGI',
#  'DIRGO',
#  'DIRGO PICARD',
#  'ALLENBY',
#  "CRUSHER'S COM VOICE",
#  'DIRGO WESLEY',
#  'BROOKS TROI',
#  'BROOKS',
#  'TROI (V.O.)',
#  'DATA TROI',
#  'KEIKO',
#  "T'PEL",
#  "V'SAL",
#  "T'PEL'S COM VOICE",
#  "NURSE'S COM VOICE",
#  "BEVERLY NURSE'S COM VOICE",
#  "RIKER T'PEL",
#  'MENDAK',
#  "MENDAK MENDAK (Cont'd)",
#  "O'BRIEN DATA (V.O.)",
#  'DATA (V.O.) BEVERLY',
#  "WORF'S COM VOICE RIKER",
#  "T'PEL/SELOK",
#  'MACET',
#  'DARO',
#  'MACET (V.O.)',
#  "O'BRIEN O'BRIEN (Cont'd)",
#  'TELLE',
#  'MAXWELL',
#  "O'BRIEN MAXWELL",
#  "MAXWELL AND O'BRIEN",
#  'MARLEY',
#  'DATA/SCROOGE',
#  'DR. CLARK (ON SCREEN)',
#  'DR. CLARK (O.C.)',
#  'DR. CLARK',
#  'JARED',
#  'ARDRA',
#  "ARDRA/FEK'LHR",
#  "DR. CLARK'S COM VOICE",
#  'TROI/ARDRA',
#  'JARED ARDRA',
#  'ARDRA/DEVIL',
#  "PICARD/FEK'LHR",
#  'MADELINE',
#  'GUNMAN',
#  'MADELINE (O.S.)',
#  'MCKNIGHT',
#  "PICARD'S COM VOICE PICARD'S COM VOICE (Cont'd)",
#  ...]

# %% [markdown]
# # To Do
#
# Filter the dataset to only have these characters:
#
# - Main Characters:
#     - Jean-Luc Picard
#     - William Riker
#     - Geordi La Forge
#     - Tasha Yar
#     - Worf
#     - Beverly Crusher
#     - Deanna Troi
#     - Data
#     - Wesley Crusher
#     - Katherine Pulaski
#     - Q
#
# Remove comm voices, voice overs (V.O) and (O.S) and everything else

# %%
# create a list of characters (TEST)
characters = ['PICARD','WORF', 'BEVERLY', 'GEORDI', 'TROI', 'TASHA', 'DATA', 'WESLEY', 'PULASKI', 'Q', 'RIKER', 'LORE']

# filtering to only the characters in the list above
StarTrek_Final = StarTrek_Cols[StarTrek_Cols['who'].isin(characters)].copy()

# %%
# checking to see if the values are correct
StarTrek_Final['who'].unique()
# Out:
# array(['PICARD', 'DATA', 'TROI', 'WORF', 'TASHA', 'RIKER', 'WESLEY',
#        'BEVERLY', 'GEORDI', 'LORE', 'PULASKI', 'Q'], dtype=object)

# %%
StarTrek_Final.shape
# Out:
# (44600, 7)

# %%
StarTrek_Cols.loc[StarTrek_Cols['who'].isin(characters)]
# Out:
#                       episode    type     who  Episode  imdbRating  Season  \
# 12      encounter at farpoint  speech  PICARD      1.0         6.9     1.0
# 13      encounter at farpoint  speech    DATA      1.0         6.9     1.0
# 14      encounter at farpoint  speech  PICARD      1.0         6.9     1.0
# 15      encounter at farpoint  speech    TROI      1.0         6.9     1.0
# 16      encounter at farpoint  speech  PICARD      1.0         6.9     1.0
# ...                       ...     ...     ...      ...         ...     ...
# 110167     all good things...  speech    DATA     25.0         8.5     7.0
# 110168     all good things...  speech  PICARD     25.0         8.5     7.0
# 110170     all good things...  speech  PICARD     25.0         8.5     7.0
# 110171     all good things...  speech    TROI     25.0         8.5     7.0
# 110173     all good things...  speech  PICARD     25.0         8.5     7.0
#
#                                                      text
# 12       You will agree, Data, that Starfleet's instru...
# 13       Difficult ... how so? Simply solve the myster...
# 14                                     As simple as that.
# 15       Farpoint Station. Even the name sounds myster...
# 16       The problem, Data, is that another life form ...
# ...                                                   ...
# 110167                            Would you care to deal?
# 110168                                   Oh... thank you.
# 110170   I should have done this a long time ago. I wa...
# 110171                           You were always welcome.
# 110173   So. Five card stud, nothing wild. The sky's t...
#
# [44600 rows x 7 columns]

# %%
StarTrek_Cols['episode'].unique().shape
# Out:
# (174,)

# %%
StarTrek_Final['who'].unique().tolist()
# Out:
# ['PICARD',
#  'DATA',
#  'TROI',
#  'WORF',
#  'TASHA',
#  'RIKER',
#  'WESLEY',
#  'BEVERLY',
#  'GEORDI',
#  'LORE',
#  'PULASKI',
#  'Q']

# %%
StarTrek_Cols.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 68487 entries, 1 to 110173
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   episode     68487 non-null  object
#  1   type        68487 non-null  object
#  2   who         68486 non-null  object
#  3   Episode     67739 non-null  float64
#  4   imdbRating  67739 non-null  float64
#  5   Season      67739 non-null  float64
#  6   text        68487 non-null  object
# dtypes: float64(3), object(4)
# memory usage: 4.2+ MB
