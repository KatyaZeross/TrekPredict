# %% [markdown]
# # Star Trek TNG - Master Clean Up
# ---
# ## INTRODUCTION
#
# - What is Star Trek? (a short history lesson)
#
# - Goal: Determine the best roster of characters using NLP and sentiment analysis to predict the highest rating on IMDB.
#     - Elaborate on applications in the real world.
#
# - Data Acquistition (link to GitHub)
#
# - Goal in this notebook is to clean the dataset, and preprocess it for modeling, along with some handy visualizations.

# %%
import pandas as pd 
import numpy as np 
import matplotlib as plt
import seaborn as sns
import dataframe_image as dfi

# %%
# read in the dataset
startrek_data = pd.read_csv(r'C:\Users\Katya\Documents\data\TNG.csv.gz', encoding= 'latin-1')

# %%
# taking a quick peek at the data
startrek_data.shape
# Out:
# (110176, 18)

# %%
# filtered to only rows where a charactor spoke in the episode
startrekspeech = startrek_data.loc[startrek_data['type'] == 'speech']

# take a look
startrekspeech.sample(3)
# Out:
#        Unnamed: 0                  episode productionnumber  \
# 971           972    encounter at farpoint              NaN
# 77638       77639            realm of fear       #40276-228
# 36942       36943  a matter of perspective       #40273-162
#
#                                                 setnames  \
# 971                                                  NaN
# 77638  USS ENTERPRISE,USS ENTERPRISE,MAIN BRIDGE,CAPT...
# 36942  USS ENTERPRISE,USS ENTERPRISE,MAIN BRIDGE,CAPT...
#
#                                               characters    act scenenumber  \
# 971                                                  NaN  OTHER         203
# 77638  PICARD,BARCLAY,RIKER,ADMIRAL HAYES,DATA,SCIENC...   FIVE         45
# 36942  PICARD,KRAG,RIKER,APGAR,DATA,MANUA,BEVERLY,TAY...    TWO         38A
#
#        scenedetails  partnumber    type       who  \
# 971             NaN         972  speech      ZORN
# 77638           NaN         569  speech   BARCLAY
# 36942           NaN         258  speech    PICARD
#
#                                                     text  speechdescription  \
# 971                      We haven't done anything wrong!              False
# 77638   But... isn't there a way to... to... to force...              False
# 36942                               Not to my knowledge.              False
#
#          Released  Episode  imdbRating     imdbID  Season
# 971    1987-09-26      1.0         6.9  tt0094030     1.0
# 77638  1992-09-26      2.0         7.2  tt0708761     6.0
# 36942  1990-02-10     14.0         6.8  tt0708671     3.0

# %%
StarTrek_Cols = startrekspeech.filter(['episode', 'type', 'who', 'Episode', 'imdbRating', 'Season', 'text'], axis=1)

StarTrek_Cols.head(10)
# Out:
#                   episode    type           who  Episode  imdbRating  Season  \
# 1   encounter at farpoint  speech   PICARD V.O.      1.0         6.9     1.0
# 3   encounter at farpoint  speech   PICARD V.O.      1.0         6.9     1.0
# 5   encounter at farpoint  speech   PICARD V.O.      1.0         6.9     1.0
# 7   encounter at farpoint  speech   PICARD V.O.      1.0         6.9     1.0
# 9   encounter at farpoint  speech   PICARD V.O.      1.0         6.9     1.0
# 12  encounter at farpoint  speech        PICARD      1.0         6.9     1.0
# 13  encounter at farpoint  speech          DATA      1.0         6.9     1.0
# 14  encounter at farpoint  speech        PICARD      1.0         6.9     1.0
# 15  encounter at farpoint  speech          TROI      1.0         6.9     1.0
# 16  encounter at farpoint  speech        PICARD      1.0         6.9     1.0
#
#                                                  text
# 1    Captain's log, stardate 42353.7. Our destinat...
# 3    My orders are to examine Farpoint, a starbase...
# 5    acquainted with my new command, this Galaxy C...
# 7    I am still somewhat in awe of its size and co...
# 9             several key positions, most notably ...
# 12   You will agree, Data, that Starfleet's instru...
# 13   Difficult ... how so? Simply solve the myster...
# 14                                 As simple as that.
# 15   Farpoint Station. Even the name sounds myster...
# 16   The problem, Data, is that another life form ...

# %%
# show a list of all the unique values within the 'who' column in order to see what needs to be cleaned. 
plt.figure()
plt.pie()
plt.show()

# pie chart of before and after cleaning/filtering goes here

StarTrek_Cols['who']
# Out:
# 1          PICARD V.O.
# 3          PICARD V.O.
# 5          PICARD V.O.
# 7          PICARD V.O.
# 9          PICARD V.O.
#               ...
# 110167            DATA
# 110168          PICARD
# 110170          PICARD
# 110171            TROI
# 110173          PICARD
# Name: who, Length: 68487, dtype: object

# %% [markdown]
# # To Do
#
# Filter the dataset to only have these characters:
#
# - Main Characters:
#     - Jean-Luc Picard
#     - William Riker
#     - Geordi La Forge
#     - Tasha Yar
#     - Worf
#     - Beverly Crusher
#     - Deanna Troi
#     - Data
#     - Wesley Crusher
#     - Katherine Pulaski
#     - Q
#
# Remove comm voices, voice overs (V.O) and (O.S) and everything else

# %%
StarTrek_Cols['who'] = StarTrek_Cols['who'].str.replace(' ', '')

# %%
characters = ['PICARD','WORF', 'BEVERLY', 'GEORDI', 'TROI', 'TASHA', 'DATA', 'WESLEY', 'PULASKI', 'Q', 'RIKER']

StarTrek_Final = StarTrek_Cols[StarTrek_Cols['who'].isin(characters)].copy()

# %%
StarTrek_Final['who'].unique()
# Out:
# array(['PICARD', 'DATA', 'TROI', 'WORF', 'TASHA', 'RIKER', 'WESLEY',
#        'BEVERLY', 'GEORDI', 'PULASKI', 'Q'], dtype=object)

# %%
StarTrek_Final.shape
# Out:
# (44460, 7)

# %%
StarTrek_Cols.loc[StarTrek_Cols['who'].isin(characters)]
# Out:
#                       episode    type     who  Episode  imdbRating  Season  \
# 12      encounter at farpoint  speech  PICARD      1.0         6.9     1.0
# 13      encounter at farpoint  speech    DATA      1.0         6.9     1.0
# 14      encounter at farpoint  speech  PICARD      1.0         6.9     1.0
# 15      encounter at farpoint  speech    TROI      1.0         6.9     1.0
# 16      encounter at farpoint  speech  PICARD      1.0         6.9     1.0
# ...                       ...     ...     ...      ...         ...     ...
# 110167     all good things...  speech    DATA     25.0         8.5     7.0
# 110168     all good things...  speech  PICARD     25.0         8.5     7.0
# 110170     all good things...  speech  PICARD     25.0         8.5     7.0
# 110171     all good things...  speech    TROI     25.0         8.5     7.0
# 110173     all good things...  speech  PICARD     25.0         8.5     7.0
#
#                                                      text
# 12       You will agree, Data, that Starfleet's instru...
# 13       Difficult ... how so? Simply solve the myster...
# 14                                     As simple as that.
# 15       Farpoint Station. Even the name sounds myster...
# 16       The problem, Data, is that another life form ...
# ...                                                   ...
# 110167                            Would you care to deal?
# 110168                                   Oh... thank you.
# 110170   I should have done this a long time ago. I wa...
# 110171                           You were always welcome.
# 110173   So. Five card stud, nothing wild. The sky's t...
#
# [44460 rows x 7 columns]

# %%
characters = ['PICARD','WORF']
StarTrek_Cols[StarTrek_Cols['who'].isin(characters)]
# Out:
#                       episode    type     who  Episode  imdbRating  Season  \
# 12      encounter at farpoint  speech  PICARD      1.0         6.9     1.0
# 14      encounter at farpoint  speech  PICARD      1.0         6.9     1.0
# 16      encounter at farpoint  speech  PICARD      1.0         6.9     1.0
# 18      encounter at farpoint  speech  PICARD      1.0         6.9     1.0
# 21      encounter at farpoint  speech  PICARD      1.0         6.9     1.0
# ...                       ...     ...     ...      ...         ...     ...
# 110129     all good things...  speech  PICARD     25.0         8.5     7.0
# 110163     all good things...  speech  PICARD     25.0         8.5     7.0
# 110168     all good things...  speech  PICARD     25.0         8.5     7.0
# 110170     all good things...  speech  PICARD     25.0         8.5     7.0
# 110173     all good things...  speech  PICARD     25.0         8.5     7.0
#
#                                                      text
# 12       You will agree, Data, that Starfleet's instru...
# 14                                     As simple as that.
# 16       The problem, Data, is that another life form ...
# 18       Data, how can you be programmed as a virtual ...
# 21                        It means 'to spy, to sneak' ...
# ...                                                   ...
# 110129   No, no... in fact, I think I'll go back to be...
# 110163   No. I just thought I might... join you this e...
# 110168                                   Oh... thank you.
# 110170   I should have done this a long time ago. I wa...
# 110173   So. Five card stud, nothing wild. The sky's t...
#
# [16521 rows x 7 columns]

# %%
StarTrek_Cols.info()
